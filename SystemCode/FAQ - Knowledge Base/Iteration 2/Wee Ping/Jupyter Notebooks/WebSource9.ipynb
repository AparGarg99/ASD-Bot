# %% [markdown]
# ## **Import Libraries**

# %%
#!pip install selenium
#!pip install webdriver-manager
#!pip install pyyaml ua-parser user-agents fake-useragent

################ WEB SCRAPING MODULES ############
from selenium import webdriver
from webdriver_manager.firefox import GeckoDriverManager
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.utils import ChromeType
from selenium.webdriver.common.by import By
import bs4
from fake_useragent import UserAgent
import requests
################ TIME MODLULES ###################
import time
from datetime import date 
import datetime
############## DATA MANIPULATION MODULES #########
import os
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords

# %% [markdown]
# ## **Define web source**

# %%
link = 'https://www.amaze.org.au/understand-autism/about-autism/'

# %% [markdown]
# ## **Read 100++ questions list**

# %%
df = pd.read_excel('ASDquestions8.xlsx',engine='openpyxl')

df[link]=np.nan
df.head(25)
# Out:
#                                              Question  \
# 0       What are the Autism Spectrum Disorders (ASD)?
# 1                               How common is autism?
# 2                What causes autism? Can it be cured?
# 3                               Is autism contagious?
# 4                     Are rates of autism increasing?
# 5                          Is autism a new condition?
# 6                         Is there a cure for autism?
# 7                            How Is Autism Diagnosed?
# 8                                Is autism permanent?
# 9                              How Is Autism Treated?
# 10                   How common is Asperger syndrome?
# 11               Different names and terms for autism
# 12     The benefits of an Asperger syndrome diagnosis
# 13  How do people with Asperger syndrome see the w...
# 14                 How Asperger syndrome is diagnosed
# 15  How can I find out if my/my child's case is ge...
# 16  How can I be sure vaccines have nothing to do ...
# 17  How can I find out what caused my child's autism?
# 18  How can I help in the search for better treatm...
# 19  What progress has been made so far in autism r...
# 20  If there is no autism epidemic, why do the aut...
# 21  How can I find the best treatments for myself ...
# 22  I think I/my child may have autism but I'm not...
# 23  Can diet help children with autism spectrum di...
# 24          What are the most common signs of autism?
#
#              https://birchtreecenter.org/learn/autism  \
# 0   ASD refers to a wide spectrum of neurodevelopm...
# 1   According to a 2020 report commissioned by the...
# 2   The causes of this complex disorder remain unc...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#    https://www.myautismteam.com/resources/autism-an-overview  \
# 0                                                 NaN
# 1   It is estimated that in the United States 1.6 ...
# 2                                                 NaN
# 3   Autism is not a contagious condition. Autism i...
# 4   Estimates released by the Centers for Disease ...
# 5   It is likely that autism has always existed, b...
# 6   There is no cure for autism. However, early in...
# 7   There is no one single conclusive test for aut...
# 8   There is some controversy on the topic of whet...
# 9   Treatment for autism depends largely on the in...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#    https://www.autism.org.uk/advice-and-guidance/what-is-autism/asperger-syndrome  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  \nAutism, including Asperger syndrome, is much...
# 11  \nOver the years, different diagnostic labels ...
# 12  \nSome people see a formal diagnosis as an unh...
# 13  \nSome people with Asperger syndrome say the w...
# 14  \nThe characteristics of Asperger syndrome var...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#                   https://iancommunity.org/autism-faq  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   There is no blood test to diagnose autism spec...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  If your child has autism and you are intereste...
# 16  Immunizations are a cornerstone of public heal...
# 17  In most individuals it is currently not possib...
# 18  In order for autism research to advance, parti...
# 19  In the past five years, scientists have made s...
# 20  Just days after my live TED talk, the Centers ...
# 21  Research suggests that early intensive behavio...
# 22  The core features of autism are difficulties w...
# 23                                                NaN
# 24                                                NaN
#
#    https://icahn.mssm.edu/research/seaver/resources/autism-faqs  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   While there is no medical test for autism, an ...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Autism research is quickly developing across m...
# 20                                                NaN
# 21                                                NaN
# 22  The first step is a conversation with your chi...
# 23  Families have reported improvements in behavio...
# 24  In toddlers, obvious symptoms may not be prese...
#
#    https://otsimo.com/en/frequently-asked-questions-autism/  \
# 0                                                 NaN
# 1   According to the U.S. Centers for Disease Cont...
# 2   You may think that something you did or ate or...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#                   https://rockmelon.com/about-autism/  \
# 0                                                 NaN
# 1   Recent studies have found that 1 in 59 childre...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   There are a number of different therapies avai...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#     https://www.amaze.org.au/understand-autism/about-autism/
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN

# %% [markdown]
# ## **Scrape QA pairs from website**

# %%
# Open webpage in a new window for scraping
#driver = webdriver.Chrome(ChromeDriverManager(chrome_type=ChromeType.GOOGLE).install())   #cannot fix in colab

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(link)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST driver version for 92.0.4515
# Driver [/home/aceirus/.wdm/drivers/chromedriver/linux64/92.0.4515.107/chromedriver] found in cache

# %%
# Parse text in webpage
source = driver.page_source
soup = bs4.BeautifulSoup(source, 'html.parser')

# %%
# Search the questions mentioned in webpage
quesList = []
#for ques in soup.find_all('h3'):
for ques in soup.find_all('button',{'class':'btn btn-unstyled'}):

    #if(ques.text[-1]=='?'):
        toSplit = str(ques.text)
        quesSplit = toSplit.split()
        quesJoin = ' '.join(quesSplit)
        
        print(quesJoin)
        quesList.append(quesJoin)
# Out:
# What causes autism?
# Secondary conditions and difficulties
# Autistic people with complex support needs
# Do autistic people look different?
# Talking about autism

# %%
# Search the answers for corresponding questions in quesList
ansList = []

#for ans in soup.find_all('div', {'class':'field-items'}):
for ans in soup.find_all('div',{'class':'card-body typography'}):

    #if ans.find(string=re.compile("autism")):
            toSplit = str(ans.text)            
            #ansSplit = toSplit.split("<br/>")
            ansClean = toSplit.replace("\n","")
            

            print(ansClean)
            print('*'*100)
            ansList.append(ansClean)
# Out:
# There is no known cause of autism.Much research is being done to try to find out more. Right now, evidence suggests that autism results from changes to the development and growth of the brain. These changes may be caused by a combination of factors, including genetics.Autism is part of who a person is. It isn’t caused by parenting or social circumstances. Autism is also not caused by vaccination or other medical treatment.
# ****************************************************************************************************
# Autism may be present with other conditions. This can affect people in different ways. Some other conditions autistic people commonly experience are:speech and language challengesintellectual disabilitysleep problemsattention problemshyperactivityepilepsyanxiety and depressionchallenges with fine and gross motor skills.There are other conditions that are associated with autism, including Fragile X Syndrome, Tuberous Sclerosis and other genetic disorders.
# ****************************************************************************************************
# Autistic people with complex support needs are people:Whose support needs span multiple domains (i.e. health, mental health, justice etc); and/orWho have high levels of need in one or more areas; and/orWho are more vulnerable or at a great risk of vulnerability than the broader autistic communityComplex support needs may be indicated by the presence of:multiple disabilitiescoexisting mental health issuespersistent and or chronic health conditionsintellectual disabilityspecific learning disabilityexperiences of trauma or neglectbehaviours of concern that can put the person or others at risk of harminteractions with multiple service systems/community supports (e.g. justice, health, mental health, child protection, housing/homelessness, and family violence).significant unmet need, such as people in remand, prison or hospital who cannot exit due to inability to find accommodationfactors for complexity within a family unit (such as multiple children or family members with a disability)factors for complexity within living arrangements ( such as share houses or residential care)access and availability to any particular supports the person is in need of; or a person who is experiencing significant difficulty in finding a provider to take them on as a client.
# ****************************************************************************************************
# Autism is a neurodevelopmental (meaning related to the brain) disability and doesn’t have any physical characteristics. This can lead to others judging autistic individuals and their families, because they may not understand why the autistic individual is behaving differently. For example, parents of autistic children sometimes report that others think that their children are badly behaved and that they lack parenting skills.Another example is autistic adults who may struggle with social situations and ‘small talk’. Social interactions are subtle and constantly changing, and autistic people may have challenges keeping up with verbal and non-verbal messages that are being communicated – their behaviour may be misunderstood and believed to be rude.Feeling judged can be very stressful for autistic people and their families. Treating them with respect, and being kind when someone is struggling can really make a difference.Learn more about autism and how you can support autistic people at Do One Thing for Autism.
# ****************************************************************************************************
# The language we useis powerful, because it helps change attitudes towards autism.Amaze respects the right of all individuals witha lived experience of autism to choose the language that most powerfully represents the way they identify.Research from the United Kingdom examined the preferences of autistic people, their families, friends and professionals around the language used to describe autism. The findings confirmed that there is no single term that everyone prefers — but they did suggest a shift towards identity-driven language, and an understanding that autism is seen as integral to the person.This shift in preference is consistent with the feedback Amaze has received from the Australian autistic community. To reflect this preference, Amaze uses the term autistic person. Read more about this decision in Amaze’s strategic plan.The term autism includes autism/autistic disorder, Asperger syndrome and Pervasive Developmental Disorder – Not Otherwise Specified (PDD-NOS).When diagnosing autism, health professionals use the term Autism Spectrum Disorder to describe the varied presentation of autistic individuals. These specific terms are also often required for diagnostic and funding purposes.You might also hear terms like high functioning, low functioning, severe and mild in an attempt to describe the extent of the challenges experienced by autistic people. However, every autistic individual has different strengths and challenges, and these terms ignore the difficulties some autistic people may experience and the capabilities of others. Amaze uses the terms high support needs and low support needs instead of high or low functioning.Amaze recognises that our community includes people with diverse viewpoints and identities. We support all autistic people, regardless of their specific diagnosis or how they identify.
# ****************************************************************************************************

# %% [markdown]
# ## **Check which questions are similar**

# %%
stop_words = set(stopwords.words('english'))

def clean_text(sent):
    sent = sent.lower() # lowercase
    sent = re.sub(r'[^\w\s]', '', sent) # remove punctuations
    sent = re.sub('Autism Spectrum Disorder','ASD',sent) # Compress term
    sent = [w for w in sent.split() if not w.lower() in stop_words] # Remove stopwords
    sent = " ".join(sent)
    return sent

# %%
def jaccard_similarity(list1, list2):
    s1 = set(list1)
    s2 = set(list2)
    return float(len(s1.intersection(s2)) / len(s1.union(s2)))

# %%
# try to match websource questions with our own 100 questions list
for c1,i in enumerate(quesList):
    i2 = clean_text(i)
    list1 = i2.split()
    
    temp1 = 0.0
    temp2 = ''
    temp3 = ''
    temp4 = 0
    
    for c2,j in enumerate(df['Question']):
        j2 = clean_text(j)
        list2 = j2.split()
            
        sim = jaccard_similarity(list1, list2)
        if(sim>temp1):
            temp1 = sim
            temp2 = j
            temp3 = i
            temp4 = c2
            
    if(temp1>=0.3):  # sim threshold
        print('Website --> ',temp3,'(Index {})'.format(c1))
        print('100 questions list --> ',temp2,'(Index {})'.format(temp4))
        print('similarity:', temp1)
        print('*'*100)
# Out:
# Website -->  What causes autism? (Index 0)
# 100 questions list -->  What causes autism? Can it be cured? (Index 2)
# similarity: 0.6666666666666666
# ****************************************************************************************************
# Website -->  Do autistic people look different? (Index 3)
# 100 questions list -->  Where do Autistic People Usually Live? (Index 135)
# similarity: 0.3333333333333333
# ****************************************************************************************************
# Website -->  Talking about autism (Index 4)
# 100 questions list -->  What is Autism? (Index 30)
# similarity: 0.5
# ****************************************************************************************************

# %%
for i in range (0,len(quesList)):
    print("Index #{0:d}: {1:s}".format(i,quesList[i]))
# Out:
# Index #0: What causes autism?
# Index #1: Secondary conditions and difficulties
# Index #2: Autistic people with complex support needs
# Index #3: Do autistic people look different?
# Index #4: Talking about autism

# %%
for i in range (0,len(ansList)):
    print("Index #{0:d}: {1:s}".format(i,ansList[i]))
# Out:
# Index #0: There is no known cause of autism.Much research is being done to try to find out more. Right now, evidence suggests that autism results from changes to the development and growth of the brain. These changes may be caused by a combination of factors, including genetics.Autism is part of who a person is. It isn’t caused by parenting or social circumstances. Autism is also not caused by vaccination or other medical treatment.
# Index #1: Autism may be present with other conditions. This can affect people in different ways. Some other conditions autistic people commonly experience are:speech and language challengesintellectual disabilitysleep problemsattention problemshyperactivityepilepsyanxiety and depressionchallenges with fine and gross motor skills.There are other conditions that are associated with autism, including Fragile X Syndrome, Tuberous Sclerosis and other genetic disorders.
# Index #2: Autistic people with complex support needs are people:Whose support needs span multiple domains (i.e. health, mental health, justice etc); and/orWho have high levels of need in one or more areas; and/orWho are more vulnerable or at a great risk of vulnerability than the broader autistic communityComplex support needs may be indicated by the presence of:multiple disabilitiescoexisting mental health issuespersistent and or chronic health conditionsintellectual disabilityspecific learning disabilityexperiences of trauma or neglectbehaviours of concern that can put the person or others at risk of harminteractions with multiple service systems/community supports (e.g. justice, health, mental health, child protection, housing/homelessness, and family violence).significant unmet need, such as people in remand, prison or hospital who cannot exit due to inability to find accommodationfactors for complexity within a family unit (such as multiple children or family members with a disability)factors for complexity within living arrangements ( such as share houses or residential care)access and availability to any particular supports the person is in need of; or a person who is experiencing significant difficulty in finding a provider to take them on as a client.
# Index #3: Autism is a neurodevelopmental (meaning related to the brain) disability and doesn’t have any physical characteristics. This can lead to others judging autistic individuals and their families, because they may not understand why the autistic individual is behaving differently. For example, parents of autistic children sometimes report that others think that their children are badly behaved and that they lack parenting skills.Another example is autistic adults who may struggle with social situations and ‘small talk’. Social interactions are subtle and constantly changing, and autistic people may have challenges keeping up with verbal and non-verbal messages that are being communicated – their behaviour may be misunderstood and believed to be rude.Feeling judged can be very stressful for autistic people and their families. Treating them with respect, and being kind when someone is struggling can really make a difference.Learn more about autism and how you can support autistic people at Do One Thing for Autism.
# Index #4: The language we useis powerful, because it helps change attitudes towards autism.Amaze respects the right of all individuals witha lived experience of autism to choose the language that most powerfully represents the way they identify.Research from the United Kingdom examined the preferences of autistic people, their families, friends and professionals around the language used to describe autism. The findings confirmed that there is no single term that everyone prefers — but they did suggest a shift towards identity-driven language, and an understanding that autism is seen as integral to the person.This shift in preference is consistent with the feedback Amaze has received from the Australian autistic community. To reflect this preference, Amaze uses the term autistic person. Read more about this decision in Amaze’s strategic plan.The term autism includes autism/autistic disorder, Asperger syndrome and Pervasive Developmental Disorder – Not Otherwise Specified (PDD-NOS).When diagnosing autism, health professionals use the term Autism Spectrum Disorder to describe the varied presentation of autistic individuals. These specific terms are also often required for diagnostic and funding purposes.You might also hear terms like high functioning, low functioning, severe and mild in an attempt to describe the extent of the challenges experienced by autistic people. However, every autistic individual has different strengths and challenges, and these terms ignore the difficulties some autistic people may experience and the capabilities of others. Amaze uses the terms high support needs and low support needs instead of high or low functioning.Amaze recognises that our community includes people with diverse viewpoints and identities. We support all autistic people, regardless of their specific diagnosis or how they identify.

# %%
# add websource answer to matched question in existing dataframe
df[link].loc[2]=ansList[0]

# %%
df[link].loc[2]
# Out:
# 'There is no known cause of autism.Much research is being done to try to find out more. Right now, evidence suggests that autism results from changes to the development and growth of the brain. These changes may be caused by a combination of factors, including genetics.Autism is part of who a person is. It isn’t caused by parenting or social circumstances. Autism is also not caused by vaccination or other medical treatment.\xa0'

# %%
# update with new valid questions list
quesListUpd = [quesList[1],
               quesList[2],
               quesList[3],
               quesList[4]]

quesListUpd
# Out:
# ['Secondary conditions and difficulties',
#  'Autistic people with complex support needs',
#  'Do autistic people look different?',
#  'Talking about autism']

# %%
# manually select answers to updated questions list
ansListUpd = [ansList[1],
              ansList[2],
              ansList[3],
              ansList[4]]

ansListUpd
# Out:
# ['Autism may be present with other conditions. This can affect people in different ways. Some other conditions autistic people commonly experience are:speech and language challengesintellectual disabilitysleep problemsattention problemshyperactivityepilepsyanxiety and depressionchallenges with fine and gross motor skills.There are other conditions that are associated with autism, including Fragile X Syndrome, Tuberous Sclerosis and other genetic disorders.',
#  'Autistic people with complex support needs are people:Whose support needs span multiple domains (i.e. health, mental health, justice etc); and/orWho have high levels of need in one or more areas; and/orWho are more vulnerable or at a great risk of vulnerability than the broader autistic communityComplex support needs may be indicated by the presence of:multiple disabilitiescoexisting mental health issuespersistent and or chronic health conditionsintellectual disabilityspecific learning disabilityexperiences of trauma or neglectbehaviours of concern that can put the person or others at risk of harminteractions with multiple service systems/community supports (e.g. justice, health, mental health, child protection, housing/homelessness, and family violence).significant unmet need, such as people in remand, prison or hospital who cannot exit due to inability to find accommodationfactors for complexity within a family unit (such as multiple children or family members with a disability)factors for complexity within living arrangements ( such as share houses or residential care)access and availability to any particular supports the person is in need of; or a person who is experiencing significant difficulty in finding a provider to take them on as a client.',
#  'Autism is a neurodevelopmental (meaning related to the brain) disability and doesn’t have any physical characteristics.\xa0This can lead to others judging autistic individuals and their families, because they may not understand why the autistic individual is behaving differently. For example, parents of autistic children sometimes report that others think that their children are badly behaved and that they lack parenting skills.Another example is autistic adults who may struggle with social situations and ‘small talk’. Social interactions are subtle and constantly changing, and autistic people may have challenges keeping up with verbal and non-verbal messages that are being communicated – their behaviour may be misunderstood and believed to be rude.Feeling judged can be very stressful for autistic people and their families. Treating them with respect, and being kind when someone is struggling can really make a difference.Learn more about autism and how you can support autistic people at Do One Thing for Autism.',
#  'The language we useis powerful, because it helps change attitudes towards autism.Amaze respects the right of all individuals witha lived experience of autism to choose the language that most powerfully represents the way they identify.Research from the United Kingdom examined the preferences of autistic people, their families, friends and professionals around the language used to describe autism. The findings confirmed that there is no single term that everyone prefers — but they did suggest a shift towards identity-driven language, and an understanding that autism is seen as integral to the person.This shift in preference is consistent with the feedback Amaze has received from the Australian autistic community. To reflect this preference, Amaze uses the term autistic person. Read more about this decision in Amaze’s strategic plan.The term autism includes autism/autistic disorder, Asperger syndrome and Pervasive Developmental Disorder – Not Otherwise Specified (PDD-NOS).When diagnosing autism, health professionals use the term Autism Spectrum Disorder to describe the varied presentation of autistic individuals. These specific terms are also often required for diagnostic and funding purposes.You might also hear terms like high functioning, low functioning, severe and mild in an attempt to describe the extent of the challenges experienced by autistic people. However, every autistic individual has different strengths and challenges, and these terms ignore the difficulties some autistic people may experience and the capabilities of others. Amaze uses the terms high support needs and low support needs instead of high or low functioning.Amaze recognises that our community includes people with diverse viewpoints and identities. We support all autistic people, regardless of their specific diagnosis or how they identify.']

# %%
# Create new dataframe with QA pairs
df2 = pd.DataFrame(zip(quesListUpd,ansListUpd),columns=['Question',link])
df2
# Out:
#                                      Question  \
# 0       Secondary conditions and difficulties
# 1  Autistic people with complex support needs
# 2          Do autistic people look different?
# 3                        Talking about autism
#
#   https://www.amaze.org.au/understand-autism/about-autism/
# 0  Autism may be present with other conditions. T...
# 1  Autistic people with complex support needs are...
# 2  Autism is a neurodevelopmental (meaning relate...
# 3  The language we useis powerful, because it hel...

# %%
# Concatenate existing and new dataframes
df3 = pd.concat([df,df2],axis=0)
df3 = df3.sort_values(by=list(df3.columns[1:])).reset_index(drop=True)
df3.head(40)
# Out:
#                                              Question  \
# 0       What are the Autism Spectrum Disorders (ASD)?
# 1                               How common is autism?
# 2                What causes autism? Can it be cured?
# 3                               Is autism contagious?
# 4                     Are rates of autism increasing?
# 5                          Is autism a new condition?
# 6                         Is there a cure for autism?
# 7                            How Is Autism Diagnosed?
# 8                                Is autism permanent?
# 9                              How Is Autism Treated?
# 10                   How common is Asperger syndrome?
# 11               Different names and terms for autism
# 12     The benefits of an Asperger syndrome diagnosis
# 13  How do people with Asperger syndrome see the w...
# 14                 How Asperger syndrome is diagnosed
# 15  How can I find out if my/my child's case is ge...
# 16  How can I be sure vaccines have nothing to do ...
# 17  How can I find out what caused my child's autism?
# 18  How can I help in the search for better treatm...
# 19  What progress has been made so far in autism r...
# 20  If there is no autism epidemic, why do the aut...
# 21  How can I find the best treatments for myself ...
# 22  I think I/my child may have autism but I'm not...
# 23  Can diet help children with autism spectrum di...
# 24          What are the most common signs of autism?
# 25                What are the treatments for autism?
# 26                         Can vaccines cause autism?
# 27  What causes autism spectrum disorder (also kno...
# 28                           Why My Child Has Autism?
# 29                            What is “the Spectrum”?
# 30                                    What is Autism?
# 31            Can My Child with Autism Attend School?
# 32                             What if I Have Autism?
# 33                                       What is ASD?
# 34  What is the difference between autism and lear...
# 35     Is autism a condition that affects only males?
# 36                               What are the causes?
# 37  Is early intervention necessary in mild cases ...
# 38                What are evidence-based therapies?
# 39  I suspect my child has autism, what should I d...
#
#              https://birchtreecenter.org/learn/autism  \
# 0   ASD refers to a wide spectrum of neurodevelopm...
# 1   According to a 2020 report commissioned by the...
# 2   The causes of this complex disorder remain unc...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#    https://www.myautismteam.com/resources/autism-an-overview  \
# 0                                                 NaN
# 1   It is estimated that in the United States 1.6 ...
# 2                                                 NaN
# 3   Autism is not a contagious condition. Autism i...
# 4   Estimates released by the Centers for Disease ...
# 5   It is likely that autism has always existed, b...
# 6   There is no cure for autism. However, early in...
# 7   There is no one single conclusive test for aut...
# 8   There is some controversy on the topic of whet...
# 9   Treatment for autism depends largely on the in...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#    https://www.autism.org.uk/advice-and-guidance/what-is-autism/asperger-syndrome  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  \nAutism, including Asperger syndrome, is much...
# 11  \nOver the years, different diagnostic labels ...
# 12  \nSome people see a formal diagnosis as an unh...
# 13  \nSome people with Asperger syndrome say the w...
# 14  \nThe characteristics of Asperger syndrome var...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#                   https://iancommunity.org/autism-faq  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   There is no blood test to diagnose autism spec...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  If your child has autism and you are intereste...
# 16  Immunizations are a cornerstone of public heal...
# 17  In most individuals it is currently not possib...
# 18  In order for autism research to advance, parti...
# 19  In the past five years, scientists have made s...
# 20  Just days after my live TED talk, the Centers ...
# 21  Research suggests that early intensive behavio...
# 22  The core features of autism are difficulties w...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#    https://icahn.mssm.edu/research/seaver/resources/autism-faqs  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   While there is no medical test for autism, an ...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Autism research is quickly developing across m...
# 20                                                NaN
# 21                                                NaN
# 22  The first step is a conversation with your chi...
# 23  Families have reported improvements in behavio...
# 24  In toddlers, obvious symptoms may not be prese...
# 25  The primary and first-line treatments include ...
# 26  There are several epidemiological studies that...
# 27  There is strong data indicating that genetics ...
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#    https://otsimo.com/en/frequently-asked-questions-autism/  \
# 0                                                 NaN
# 1   According to the U.S. Centers for Disease Cont...
# 2   You may think that something you did or ate or...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  Although mostly there is not one cause that ca...
# 29  Autism is a term that is constantly redefined ...
# 30  Autism spectrum disorder is an umbrella term u...
# 31  Every child has the right to get appropriate e...
# 32  You should consider consulting your doctor for...
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#                   https://rockmelon.com/about-autism/  \
# 0                                                 NaN
# 1   Recent studies have found that 1 in 59 childre...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   There are a number of different therapies avai...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30  Autism, also known as Autism Spectrum Disorder...
# 31                                                NaN
# 32                                                NaN
# 33  ASD is the acronym for ‘Autism Spectrum Disord...
# 34  Autism and learning disabilities can occur tog...
# 35  Autism spectrum disorder is more common in mal...
# 36  Currently, there is no single known cause for ...
# 37  Early intervention is recommended for all chil...
# 38  Evidence-based therapy means that there has be...
# 39  If you suspect your child has autism and you d...
#
#    https://www.amaze.org.au/understand-autism/about-autism/
# 0                                                 NaN
# 1                                                 NaN
# 2   There is no known cause of autism.Much researc...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN

# %% [markdown]
# ## **Save Output**

# %%
df3.to_excel('ASDquestions9.xlsx',index=False)
