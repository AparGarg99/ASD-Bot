# %% [markdown]
# ## **Import Libraries**

# %%
#!pip install selenium
#!pip install webdriver-manager
#!pip install pyyaml ua-parser user-agents fake-useragent

################ WEB SCRAPING MODULES ############
from selenium import webdriver
from webdriver_manager.firefox import GeckoDriverManager
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.utils import ChromeType
from selenium.webdriver.common.by import By
import bs4
from fake_useragent import UserAgent
import requests
################ TIME MODLULES ###################
import time
from datetime import date 
import datetime
############## DATA MANIPULATION MODULES #########
import os
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords

# %% [markdown]
# ## **Define web source**

# %%
link = 'https://rockmelon.com/about-autism/'

# %% [markdown]
# ## **Read 100++ questions list**

# %%
df = pd.read_excel('ASDquestions7.xlsx',engine='openpyxl')

df[link]=np.nan
df.head(25)
# Out:
#                                              Question  \
# 0       What are the Autism Spectrum Disorders (ASD)?
# 1                               How common is autism?
# 2                What causes autism? Can it be cured?
# 3                               Is autism contagious?
# 4                     Are rates of autism increasing?
# 5                          Is autism a new condition?
# 6                         Is there a cure for autism?
# 7                            How Is Autism Diagnosed?
# 8                                Is autism permanent?
# 9                              How Is Autism Treated?
# 10                   How common is Asperger syndrome?
# 11               Different names and terms for autism
# 12     The benefits of an Asperger syndrome diagnosis
# 13  How do people with Asperger syndrome see the w...
# 14                 How Asperger syndrome is diagnosed
# 15  How can I find out if my/my child's case is ge...
# 16  How can I be sure vaccines have nothing to do ...
# 17  How can I find out what caused my child's autism?
# 18  How can I help in the search for better treatm...
# 19  What progress has been made so far in autism r...
# 20  If there is no autism epidemic, why do the aut...
# 21  How can I find the best treatments for myself ...
# 22  I think I/my child may have autism but I'm not...
# 23  Can diet help children with autism spectrum di...
# 24          What are the most common signs of autism?
#
#              https://birchtreecenter.org/learn/autism  \
# 0   ASD refers to a wide spectrum of neurodevelopm...
# 1   According to a 2020 report commissioned by the...
# 2   The causes of this complex disorder remain unc...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#    https://www.myautismteam.com/resources/autism-an-overview  \
# 0                                                 NaN
# 1   It is estimated that in the United States 1.6 ...
# 2                                                 NaN
# 3   Autism is not a contagious condition. Autism i...
# 4   Estimates released by the Centers for Disease ...
# 5   It is likely that autism has always existed, b...
# 6   There is no cure for autism. However, early in...
# 7   There is no one single conclusive test for aut...
# 8   There is some controversy on the topic of whet...
# 9   Treatment for autism depends largely on the in...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#    https://www.autism.org.uk/advice-and-guidance/what-is-autism/asperger-syndrome  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  \nAutism, including Asperger syndrome, is much...
# 11  \nOver the years, different diagnostic labels ...
# 12  \nSome people see a formal diagnosis as an unh...
# 13  \nSome people with Asperger syndrome say the w...
# 14  \nThe characteristics of Asperger syndrome var...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#                   https://iancommunity.org/autism-faq  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   There is no blood test to diagnose autism spec...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  If your child has autism and you are intereste...
# 16  Immunizations are a cornerstone of public heal...
# 17  In most individuals it is currently not possib...
# 18  In order for autism research to advance, parti...
# 19  In the past five years, scientists have made s...
# 20  Just days after my live TED talk, the Centers ...
# 21  Research suggests that early intensive behavio...
# 22  The core features of autism are difficulties w...
# 23                                                NaN
# 24                                                NaN
#
#    https://icahn.mssm.edu/research/seaver/resources/autism-faqs  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   While there is no medical test for autism, an ...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Autism research is quickly developing across m...
# 20                                                NaN
# 21                                                NaN
# 22  The first step is a conversation with your chi...
# 23  Families have reported improvements in behavio...
# 24  In toddlers, obvious symptoms may not be prese...
#
#    https://otsimo.com/en/frequently-asked-questions-autism/  \
# 0                                                 NaN
# 1   According to the U.S. Centers for Disease Cont...
# 2   You may think that something you did or ate or...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#     https://rockmelon.com/about-autism/
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
# 15                                  NaN
# 16                                  NaN
# 17                                  NaN
# 18                                  NaN
# 19                                  NaN
# 20                                  NaN
# 21                                  NaN
# 22                                  NaN
# 23                                  NaN
# 24                                  NaN

# %% [markdown]
# ## **Scrape QA pairs from website**

# %%
# Open webpage in a new window for scraping
#driver = webdriver.Chrome(ChromeDriverManager(chrome_type=ChromeType.GOOGLE).install())   #cannot fix in colab

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(link)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST driver version for 92.0.4515
# Driver [/home/aceirus/.wdm/drivers/chromedriver/linux64/92.0.4515.107/chromedriver] found in cache

# %%
# Parse text in webpage
source = driver.page_source
soup = bs4.BeautifulSoup(source, 'html.parser')

# %%
# Search the questions mentioned in webpage
quesList = []
for ques in soup.find_all('h5'):
    #if(ques.text[-1]=='?'):
        toSplit = str(ques)
        quesSplit = toSplit.split(". ")
        quesClean = quesSplit[1].replace("</h5>","")
        
        print(quesClean)
        quesList.append(quesClean)
# Out:
# What is Autism?
# What is ASD?
# What are the causes?
# What are evidence-based therapies?
# How common is autism?
# I suspect my child has autism, what should I do next?
# How is autism diagnosed?
# What therapies are available for ASD?
# How can I help my child with autism?
# What are the early signs of autism?
# What age do children usually start to show signs of autism?
# What age can a child be tested for autism?
# Is early intervention necessary in mild cases of autism?
# How early can you start treatment for autism?
# Is autism a condition that affects only males?
# Does autism often occur with other disorders?
# What is the difference between autism and learning disabilities?

# %%
# Search the answers for corresponding questions in quesList
ansList = []

#for ans in soup.find_all('div', {'class':'field-items'}):
for ans in soup.find_all('p', {'style':'font-size:15px'}):

    #if ans.find(string=re.compile("autism")):
            #toSplit = str(ans)            
            #ansSplit = toSplit.split("<br/>")
            #ansClean = ansSplit[1].replace("</p>","")

            print(ans.text)
            print('*'*100)
            ansList.append(ans.text)
# Out:
# Autism, also known as Autism Spectrum Disorder (ASD), is a life-long condition (Autism Awareness Australia, 2018). People with ASD often experience difficulties with communication, social interaction and restricted/repetitive interests and behaviours (Autism Awareness Australia, 2018). While there is no single known cause associated with autism, the numbers of children diagnosed has steadily increased over the years (Autism Awareness Australia, 2018).
# ****************************************************************************************************
# However, the thing is, there is no one way that autism can affect a person. Every individual on the autism spectrum will present differently. There is a saying, “if you’ve met one person with autism, then you’ve met one person with autism.”
# ****************************************************************************************************
# ASD is the acronym for ‘Autism Spectrum Disorder’. This umbrella term includes autistic disorder (also known as “classic autism”), Asperger’s disorder, and pervasive developmental disorder not otherwise specified (also known as “atypical autism”) according to the Fourth Edition of the Diagnostic and Statistical Manual of Mental Disorders (DSM) issued in 1992 (Autism Awareness Australia, 2018).
# ****************************************************************************************************
# The DSM was published by the American Psychiatric Association and serves as the primary manual used by clinicians in the U.S., Australia, and many other countries to provide the formal criteria for various diagnoses, including autism (Autism Awareness Australia, 2018).
# ****************************************************************************************************
# Currently, there is no single known cause for autism, however, recent research has identified strong genetic links (Autism Awareness Australia, 2018). We do know though that autism is NOT caused by an individual’s upbringing, their social or economic circumstances, nor is it caused by vaccines or bad parenting!
# ****************************************************************************************************
# Evidence-based therapy means that there has been some conclusive research to prove the effects of a therapy on its potential users (Autism Awareness Australia, 2018). Whilst many treatments claim to have evidence proving they work, in many cases, there has actually been no extensive top level research done (Autism Awareness Australia, 2018).
# ****************************************************************************************************
# At Rockmelon, our content is completely evidence-based. All content has been developed with the help of a team of clinicians, parents and experts in the autism field from around the world.
# ****************************************************************************************************
# Recent studies have found that 1 in 59 children have an ASD diagnosis (Centers for Disease Control, 2018) Autism is around 4.5 times more common in boys than girls, however around 1 in 189 girls have an ASD diagnosis (Centers for Disease Control, 2018).
# ****************************************************************************************************
# About 150 children are diagnosed with ASD every hour (Centers for Disease Control, 2018). Recent studies have also shown that the number of children diagnosed with ASD has also increased over the years with no single known cause (Centers for Disease Control, 2018).
# ****************************************************************************************************
# If you suspect your child has autism and you do not have a diagnosis yet, don’t wait! Start early intervention. We at Rockmelon believe that as a parent, you know your child best. If you think your child may have a delay or you are in the process of getting a diagnosis there is no harm in getting started early. It is the ‘early’ in early intervention that makes all the difference.
# ****************************************************************************************************
# If it turns out that your child doesn’t have a developmental delay, many of the skills Rockmelon promotes are applicable to neurotypical children as well.
# ****************************************************************************************************
# “Most people find the diagnosis process quite confronting. It’s not much fun having someone point out all the things that your child can’t do, things that typical children just pick up naturally. But think of this assessment as a benchmark, against which you can measure your child’s progress once they start in an intervention program.”
# ****************************************************************************************************
# – Seana Smith, mother of four and co-author, Australian autism handbook
# ****************************************************************************************************
#  If you suspect that your child has a developmental delay it is vital to get a full assessment and diagnosis from a qualified and reliable professional or team of professionals using proper assessment tools (Autism Awareness Australia, 2018).
# ****************************************************************************************************
# While the diagnostic criteria for autism under the Fifth Edition of the Diagnostic and Statistical Manual of Mental Disorders (DSM-5) are consistent, the requirements of who can formally make a diagnosis can differ from country to country (Autism Awareness Australia, 2018).
# ****************************************************************************************************
# For instance, some countries require that a child be diagnosed by a multi-disciplinary panel, while other countries allow a single specialist (e.g. developmental paediatrician) to make the diagnosis on their own (Autism Awareness Australia, 2018). In each country, different states might also have different requirements.
# ****************************************************************************************************
# There are a number of different therapies available to help assist a child with autism reach their fullest potential.
# ****************************************************************************************************
# If you are new to the world of autism, you might find yourself floating in a pool of different therapy terms – from occupational therapy to speech pathology, to speech and language therapy to cognitive behaviour therapy. You might also be thinking, which are the ones that your child will need? What if they don’t work? The other thing to note is that something that worked for another family, may not necessarily be of the same benefit for your child.
# ****************************************************************************************************
# If you suspect your child may have a developmental delay, the best thing you can do is start investigating as soon as possible (Autism Awareness Australia, 2018).
# ****************************************************************************************************
# If you think your child may have a delay or you are in the process of getting a diagnosis there is no harm in getting started early. It is the ‘early’ in early intervention that makes all the difference.
# ****************************************************************************************************
# Rockmelon CONNECT+LEARN has been designed to help parents who have a child with additional needs. Children with autism can learn, it is just a matter of teaching a little differently. Rockmelon CONNECT+LEARN provides you with all the  necessary tools and information parents need to help deliver better outcomes for their children.
# ****************************************************************************************************
# Some of the common traits associated with autism are difficulties with communication, social interaction, restricted/repetitive interests and behaviours, behavioural challenges and sensory issues (Autism Awareness Australia, 2018). One child might display all of these, another might display one or two, and another might display none at all. Often, one of the first things parents report noticing is a lack of communication skills. These early signs can present differently in every single child.
# ****************************************************************************************************
# Remember, some children are just late to talk and it doesn’t immediately mean they have autism. If you are concerned that your child may have a developmental delay, the best thing you can do is get in contact with your family doctor or paediatrician. Don’t wait for a diagnosis to start working with your child to develop some of the skills they may need help with.
# ****************************************************************************************************
# The most common age for parents to first become concerned about autism is around 15-18 months, usually because their toddler’s speech isn’t developing. Children may have speech delay, however, and not have an autism spectrum disorder (ASD). It’s problems with nonverbal social communication that are the real pointers to autism.
# ****************************************************************************************************
# For example, young children with ASD don’t usually:
# ****************************************************************************************************
# Some of these signs may be visible before twelve months of age, but if a child sits, crawls, and walks on time they can be easily missed by parents. There are children on the autism spectrum who are highly verbal and as pre-schoolers may even have precocious speech. In this situation it’s even easier for their autism to be missed.
# ****************************************************************************************************
# Their problems may not become obvious until they attend school and social difficulties — such as trouble making friends and acting out in class — start to affect their progress and self-esteem.
# ****************************************************************************************************
# There are scientifically validated tests, such as the M-CHAT, that can be used to screen for autism in children as young as 15-18 months. Screening tests, however, are not a diagnosis and will pick up some children who don’t go on to have ASD. What screening tests do is point to social problems that should be investigated by a health professional, such as a paediatrician or child psychologist.
# ****************************************************************************************************
# For some children with ASD, a diagnosis can be reliably made at the age of two years by an experienced professional, although a more common age for diagnosis is around 3-5 years.
# ****************************************************************************************************
# The earlier a child receives a diagnosis the better, as it means they can start on early intervention to help address their social and behavioural challenges.
# ****************************************************************************************************
# Early intervention is recommended for all children with an autism spectrum disorder.
# ****************************************************************************************************
# A ‘mild’ case of autism in early childhood can lead to major problems once a child reaches their school and teenage years. Symptoms such as inflexibility and ‘social blindness’ can lead to run ins with teachers and isolation and bullying from peers. Young people on the spectrum are much more likely than their classmates to suffer from anxiety and depression as a result. If a child’s challenges can be targeted early, we are offering them a better chance of negotiating their school years with success.
# ****************************************************************************************************
# In fact, research evidence shows that children with milder symptoms respond best to early intervention, with these benefits sustained in the long-term.
# ****************************************************************************************************
# The simple answer is as early as possible. Treatment can commence before a child receives an official diagnosis if autism is strongly suspected.
# ****************************************************************************************************
# In early childhood, the brain is more ‘plastic’ or able to be changed than at older ages, offering the greatest potential for long-term change.
# ****************************************************************************************************
# There are now play-based early intervention programs for ASD, such as the Early Start Denver Model, that target toddlers as young as 18 months. Studies show improvements in learning and language as well as reduced symptoms of autism, with these benefits maintained when the children were followed-up two years later.
# ****************************************************************************************************
# There is research to suggest children progress faster when treatment commences before the age of four, but all young people with ASD, no matter what age, can benefit from science-based interventions.
# ****************************************************************************************************
# Autism spectrum disorder is more common in males, along with a number of other developmental disorders, such as ADHD and learning disabilities.
# ****************************************************************************************************
# Overall, statistics show that ASD is about 4 times more common among boys than girls. That said, ASD often escapes detection in girls and young women. Girls appear to be more skilled at masking their symptoms, copying the behaviour of friends and classmates and finding ways to fit in. Unfortunately, this often comes at the cost of severe anxiety and depression. It’s not uncommon for girls with ASD not to receive a diagnosis until they reach adulthood. With better recognition of autism in females, there may come a time when the male to female ratio moves closer to 2 or 3 to 1.
# ****************************************************************************************************
# Yes, autism often occurs alongside other conditions, including intellectual disability, seizure disorder (epilepsy), language delay, attention deficit hyperactivity disorder (ADHD) and behaviour disorders such as oppositional defiant disorder, as well as anxiety and genetic disorders such as Fragile X and Down Syndrome.
# ****************************************************************************************************
# Sometimes these other conditions will have a greater impact on a child’s ability to function at school and home than the autism itself.
# ****************************************************************************************************
# Intellectual disability and autism spectrum disorder frequently occur together. A child with ASD and an intellectual disability will have problems with thinking, memory and learning and take longer to learn new skills and behaviours than a child without this diagnosis. With the right support, however, all children can learn.
# ****************************************************************************************************
# Autism and learning disabilities can occur together, however autism spectrum disorder is not a learning disability.
# ****************************************************************************************************
# Learning disabilities, also referred to as specific learning disorders, are usually identified once a child is in school and are more commonly associated with ADHD (which also can co-occur with autism). They refer to serious and ongoing problems in one of three areas — reading, writing and mathematics. A well-known learning disorder is dyslexia, which affects reading and spelling and often runs in families.
# ****************************************************************************************************
# While not all children with ASD will be diagnosed with a specific learning disorder, it’s not uncommon for even very bright children with ASD to have an uneven pattern of skills, where they are gifted at maths but struggle with reading or writing, or vice versa.
# ****************************************************************************************************

# %% [markdown]
# ## **Check which questions are similar**

# %%
stop_words = set(stopwords.words('english'))

def clean_text(sent):
    sent = sent.lower() # lowercase
    sent = re.sub(r'[^\w\s]', '', sent) # remove punctuations
    sent = re.sub('Autism Spectrum Disorder','ASD',sent) # Compress term
    sent = [w for w in sent.split() if not w.lower() in stop_words] # Remove stopwords
    sent = " ".join(sent)
    return sent

# %%
def jaccard_similarity(list1, list2):
    s1 = set(list1)
    s2 = set(list2)
    return float(len(s1.intersection(s2)) / len(s1.union(s2)))

# %%
# try to match websource questions with our own 100 questions list
for c1,i in enumerate(quesList):
    i2 = clean_text(i)
    list1 = i2.split()
    
    temp1 = 0.0
    temp2 = ''
    temp3 = ''
    temp4 = 0
    
    for c2,j in enumerate(df['Question']):
        j2 = clean_text(j)
        list2 = j2.split()
            
        sim = jaccard_similarity(list1, list2)
        if(sim>temp1):
            temp1 = sim
            temp2 = j
            temp3 = i
            temp4 = c2
            
    if(temp1>=0.3):  # sim threshold
        print('Website --> ',temp3,'(Index {})'.format(c1))
        print('100 questions list --> ',temp2,'(Index {})'.format(temp4))
        print('similarity:', temp1)
        print('*'*100)
# Out:
# Website -->  What is Autism? (Index 0)
# 100 questions list -->  What is Autism? (Index 30)
# similarity: 1.0
# ****************************************************************************************************
# Website -->  What are the causes? (Index 2)
# 100 questions list -->  What causes autism? Can it be cured? (Index 2)
# similarity: 0.3333333333333333
# ****************************************************************************************************
# Website -->  How common is autism? (Index 4)
# 100 questions list -->  How common is autism? (Index 1)
# similarity: 1.0
# ****************************************************************************************************
# Website -->  I suspect my child has autism, what should I do next? (Index 5)
# 100 questions list -->  Why My Child Has Autism? (Index 28)
# similarity: 0.5
# ****************************************************************************************************
# Website -->  How is autism diagnosed?  (Index 6)
# 100 questions list -->  How Is Autism Diagnosed? (Index 7)
# similarity: 1.0
# ****************************************************************************************************
# Website -->  How can I help my child with autism? (Index 8)
# 100 questions list -->  Why My Child Has Autism? (Index 28)
# similarity: 0.6666666666666666
# ****************************************************************************************************
# Website -->  What are the early signs of autism? (Index 9)
# 100 questions list -->  What are the most common signs of autism? (Index 24)
# similarity: 0.5
# ****************************************************************************************************
# Website -->  What age can a child be tested for autism? (Index 11)
# 100 questions list -->  Can I wait to have my child tested for Autism? (Index 51)
# similarity: 0.6
# ****************************************************************************************************
# Website -->  Is autism a condition that affects only males? (Index 14)
# 100 questions list -->  Is autism a new condition? (Index 5)
# similarity: 0.4
# ****************************************************************************************************
# Website -->  Does autism often occur with other disorders?   (Index 15)
# 100 questions list -->  What are the Autism Spectrum Disorders (ASD)? (Index 0)
# similarity: 0.3333333333333333
# ****************************************************************************************************
# Website -->  What is the difference between autism and learning disabilities? (Index 16)
# 100 questions list -->  What are some resources for learning more about autism? (Index 130)
# similarity: 0.4
# ****************************************************************************************************

# %%
for i in range (0,len(quesList)):
    print("Index #{0:d}: {1:s}".format(i,quesList[i]))
# Out:
# Index #0: What is Autism?
# Index #1: What is ASD?
# Index #2: What are the causes?
# Index #3: What are evidence-based therapies?
# Index #4: How common is autism?
# Index #5: I suspect my child has autism, what should I do next?
# Index #6: How is autism diagnosed?
# Index #7: What therapies are available for ASD?
# Index #8: How can I help my child with autism?
# Index #9: What are the early signs of autism?
# Index #10: What age do children usually start to show signs of autism?
# Index #11: What age can a child be tested for autism?
# Index #12: Is early intervention necessary in mild cases of autism?
# Index #13: How early can you start treatment for autism?
# Index #14: Is autism a condition that affects only males?
# Index #15: Does autism often occur with other disorders?
# Index #16: What is the difference between autism and learning disabilities?

# %%
for i in range (0,len(ansList)):
    print("Index #{0:d}: {1:s}".format(i,ansList[i]))
# Out:
# Index #0: Autism, also known as Autism Spectrum Disorder (ASD), is a life-long condition (Autism Awareness Australia, 2018). People with ASD often experience difficulties with communication, social interaction and restricted/repetitive interests and behaviours (Autism Awareness Australia, 2018). While there is no single known cause associated with autism, the numbers of children diagnosed has steadily increased over the years (Autism Awareness Australia, 2018).
# Index #1: However, the thing is, there is no one way that autism can affect a person. Every individual on the autism spectrum will present differently. There is a saying, “if you’ve met one person with autism, then you’ve met one person with autism.”
# Index #2: ASD is the acronym for ‘Autism Spectrum Disorder’. This umbrella term includes autistic disorder (also known as “classic autism”), Asperger’s disorder, and pervasive developmental disorder not otherwise specified (also known as “atypical autism”) according to the Fourth Edition of the Diagnostic and Statistical Manual of Mental Disorders (DSM) issued in 1992 (Autism Awareness Australia, 2018).
# Index #3: The DSM was published by the American Psychiatric Association and serves as the primary manual used by clinicians in the U.S., Australia, and many other countries to provide the formal criteria for various diagnoses, including autism (Autism Awareness Australia, 2018).
# Index #4: Currently, there is no single known cause for autism, however, recent research has identified strong genetic links (Autism Awareness Australia, 2018). We do know though that autism is NOT caused by an individual’s upbringing, their social or economic circumstances, nor is it caused by vaccines or bad parenting!
# Index #5: Evidence-based therapy means that there has been some conclusive research to prove the effects of a therapy on its potential users (Autism Awareness Australia, 2018). Whilst many treatments claim to have evidence proving they work, in many cases, there has actually been no extensive top level research done (Autism Awareness Australia, 2018).
# Index #6: At Rockmelon, our content is completely evidence-based. All content has been developed with the help of a team of clinicians, parents and experts in the autism field from around the world.
# Index #7: Recent studies have found that 1 in 59 children have an ASD diagnosis (Centers for Disease Control, 2018) Autism is around 4.5 times more common in boys than girls, however around 1 in 189 girls have an ASD diagnosis (Centers for Disease Control, 2018).
# Index #8: About 150 children are diagnosed with ASD every hour (Centers for Disease Control, 2018). Recent studies have also shown that the number of children diagnosed with ASD has also increased over the years with no single known cause (Centers for Disease Control, 2018).
# Index #9: If you suspect your child has autism and you do not have a diagnosis yet, don’t wait! Start early intervention. We at Rockmelon believe that as a parent, you know your child best. If you think your child may have a delay or you are in the process of getting a diagnosis there is no harm in getting started early. It is the ‘early’ in early intervention that makes all the difference.
# Index #10: If it turns out that your child doesn’t have a developmental delay, many of the skills Rockmelon promotes are applicable to neurotypical children as well.
# Index #11: “Most people find the diagnosis process quite confronting. It’s not much fun having someone point out all the things that your child can’t do, things that typical children just pick up naturally. But think of this assessment as a benchmark, against which you can measure your child’s progress once they start in an intervention program.”
# Index #12: – Seana Smith, mother of four and co-author, Australian autism handbook
# Index #13:  If you suspect that your child has a developmental delay it is vital to get a full assessment and diagnosis from a qualified and reliable professional or team of professionals using proper assessment tools (Autism Awareness Australia, 2018).
# Index #14: While the diagnostic criteria for autism under the Fifth Edition of the Diagnostic and Statistical Manual of Mental Disorders (DSM-5) are consistent, the requirements of who can formally make a diagnosis can differ from country to country (Autism Awareness Australia, 2018).
# Index #15: For instance, some countries require that a child be diagnosed by a multi-disciplinary panel, while other countries allow a single specialist (e.g. developmental paediatrician) to make the diagnosis on their own (Autism Awareness Australia, 2018). In each country, different states might also have different requirements.
# Index #16: There are a number of different therapies available to help assist a child with autism reach their fullest potential.
# Index #17: If you are new to the world of autism, you might find yourself floating in a pool of different therapy terms – from occupational therapy to speech pathology, to speech and language therapy to cognitive behaviour therapy. You might also be thinking, which are the ones that your child will need? What if they don’t work? The other thing to note is that something that worked for another family, may not necessarily be of the same benefit for your child.
# Index #18: If you suspect your child may have a developmental delay, the best thing you can do is start investigating as soon as possible (Autism Awareness Australia, 2018).
# Index #19: If you think your child may have a delay or you are in the process of getting a diagnosis there is no harm in getting started early. It is the ‘early’ in early intervention that makes all the difference.
# Index #20: Rockmelon CONNECT+LEARN has been designed to help parents who have a child with additional needs. Children with autism can learn, it is just a matter of teaching a little differently. Rockmelon CONNECT+LEARN provides you with all the  necessary tools and information parents need to help deliver better outcomes for their children.
# Index #21: Some of the common traits associated with autism are difficulties with communication, social interaction, restricted/repetitive interests and behaviours, behavioural challenges and sensory issues (Autism Awareness Australia, 2018). One child might display all of these, another might display one or two, and another might display none at all. Often, one of the first things parents report noticing is a lack of communication skills. These early signs can present differently in every single child.
# Index #22: Remember, some children are just late to talk and it doesn’t immediately mean they have autism. If you are concerned that your child may have a developmental delay, the best thing you can do is get in contact with your family doctor or paediatrician. Don’t wait for a diagnosis to start working with your child to develop some of the skills they may need help with.
# Index #23: The most common age for parents to first become concerned about autism is around 15-18 months, usually because their toddler’s speech isn’t developing. Children may have speech delay, however, and not have an autism spectrum disorder (ASD). It’s problems with nonverbal social communication that are the real pointers to autism.
# Index #24: For example, young children with ASD don’t usually:
# Index #25: Some of these signs may be visible before twelve months of age, but if a child sits, crawls, and walks on time they can be easily missed by parents. There are children on the autism spectrum who are highly verbal and as pre-schoolers may even have precocious speech. In this situation it’s even easier for their autism to be missed.
# Index #26: Their problems may not become obvious until they attend school and social difficulties — such as trouble making friends and acting out in class — start to affect their progress and self-esteem.
# Index #27: There are scientifically validated tests, such as the M-CHAT, that can be used to screen for autism in children as young as 15-18 months. Screening tests, however, are not a diagnosis and will pick up some children who don’t go on to have ASD. What screening tests do is point to social problems that should be investigated by a health professional, such as a paediatrician or child psychologist.
# Index #28: For some children with ASD, a diagnosis can be reliably made at the age of two years by an experienced professional, although a more common age for diagnosis is around 3-5 years.
# Index #29: The earlier a child receives a diagnosis the better, as it means they can start on early intervention to help address their social and behavioural challenges.
# Index #30: Early intervention is recommended for all children with an autism spectrum disorder.
# Index #31: A ‘mild’ case of autism in early childhood can lead to major problems once a child reaches their school and teenage years. Symptoms such as inflexibility and ‘social blindness’ can lead to run ins with teachers and isolation and bullying from peers. Young people on the spectrum are much more likely than their classmates to suffer from anxiety and depression as a result. If a child’s challenges can be targeted early, we are offering them a better chance of negotiating their school years with success.
# Index #32: In fact, research evidence shows that children with milder symptoms respond best to early intervention, with these benefits sustained in the long-term.
# Index #33: The simple answer is as early as possible. Treatment can commence before a child receives an official diagnosis if autism is strongly suspected.
# Index #34: In early childhood, the brain is more ‘plastic’ or able to be changed than at older ages, offering the greatest potential for long-term change.
# Index #35: There are now play-based early intervention programs for ASD, such as the Early Start Denver Model, that target toddlers as young as 18 months. Studies show improvements in learning and language as well as reduced symptoms of autism, with these benefits maintained when the children were followed-up two years later.
# Index #36: There is research to suggest children progress faster when treatment commences before the age of four, but all young people with ASD, no matter what age, can benefit from science-based interventions.
# Index #37: Autism spectrum disorder is more common in males, along with a number of other developmental disorders, such as ADHD and learning disabilities.
# Index #38: Overall, statistics show that ASD is about 4 times more common among boys than girls. That said, ASD often escapes detection in girls and young women. Girls appear to be more skilled at masking their symptoms, copying the behaviour of friends and classmates and finding ways to fit in. Unfortunately, this often comes at the cost of severe anxiety and depression. It’s not uncommon for girls with ASD not to receive a diagnosis until they reach adulthood. With better recognition of autism in females, there may come a time when the male to female ratio moves closer to 2 or 3 to 1.
# Index #39: Yes, autism often occurs alongside other conditions, including intellectual disability, seizure disorder (epilepsy), language delay, attention deficit hyperactivity disorder (ADHD) and behaviour disorders such as oppositional defiant disorder, as well as anxiety and genetic disorders such as Fragile X and Down Syndrome.
# Index #40: Sometimes these other conditions will have a greater impact on a child’s ability to function at school and home than the autism itself.
# Index #41: Intellectual disability and autism spectrum disorder frequently occur together. A child with ASD and an intellectual disability will have problems with thinking, memory and learning and take longer to learn new skills and behaviours than a child without this diagnosis. With the right support, however, all children can learn.
# Index #42: Autism and learning disabilities can occur together, however autism spectrum disorder is not a learning disability.
# Index #43: Learning disabilities, also referred to as specific learning disorders, are usually identified once a child is in school and are more commonly associated with ADHD (which also can co-occur with autism). They refer to serious and ongoing problems in one of three areas — reading, writing and mathematics. A well-known learning disorder is dyslexia, which affects reading and spelling and often runs in families.
# Index #44: While not all children with ASD will be diagnosed with a specific learning disorder, it’s not uncommon for even very bright children with ASD to have an uneven pattern of skills, where they are gifted at maths but struggle with reading or writing, or vice versa.

# %%
# add websource answer to matched question in existing dataframe
df[link].loc[30]=ansList[0]+ansList[1] #0
df[link].loc[1]=ansList[7]+ansList[8] #4
df[link].loc[7]=ansList[16]+ansList[17] #6
df[link].loc[51]=ansList[27]+ansList[28]+ansList[29] #11

# %%
df[link].loc[51]
# Out:
# 'There are scientifically validated tests, such as the M-CHAT, that can be used to screen for autism in children as young as 15-18 months. Screening tests, however, are not a diagnosis and will pick up some children who don’t go on to have ASD. What screening tests do is point to social problems that should be investigated by a health professional, such as a paediatrician or child psychologist. For some children with ASD, a diagnosis can be reliably made at the age of two years by an experienced professional, although a more common age for diagnosis is around 3-5 years. The earlier a child receives a diagnosis the better, as it means they can start on early intervention to help address their social and behavioural challenges.'

# %%
# update with new valid questions list
quesListUpd = [quesList[1],
               quesList[2],
               quesList[3],
               quesList[5],
               quesList[7],
               quesList[8],
               quesList[9],
               quesList[10],
               quesList[12],
               quesList[13],
               quesList[14],
               quesList[15],
               quesList[16]]
quesListUpd
# Out:
# ['What is ASD?',
#  'What are the causes?',
#  'What are evidence-based therapies? ',
#  'I suspect my child has autism, what should I do next?',
#  'What therapies are available for ASD?',
#  'How can I help my child with autism?',
#  'What are the early signs of autism?',
#  'What age do children usually start to show signs of autism?',
#  'Is early intervention necessary in mild cases of autism?',
#  'How early can you start treatment for autism?',
#  'Is autism a condition that affects only males?',
#  'Does autism often occur with other disorders? \xa0',
#  'What is the difference between autism and learning disabilities?']

# %%
# manually select answers to updated questions list
ansListUpd = [ansList[2]+ansList[3],
              ansList[4],
              ansList[5]+ansList[6],
              ansList[9]+ansList[10],
              ansList[16]+ansList[17],
              ansList[18]+ansList[19]+ansList[20],
              ansList[21]+ansList[22],
              ansList[23]+ansList[24]+ansList[26],
              ansList[30]+ansList[31]+ansList[32],
              ansList[33]+ansList[34]+ansList[35]+ansList[36],
              ansList[37]+ansList[38],
              ansList[39]+ansList[40]+ansList[41],
              ansList[42]+ansList[43]+ansList[44]]

ansListUpd
# Out:
# ['ASD is the acronym for ‘Autism Spectrum Disorder’. This umbrella term includes autistic disorder (also known as “classic autism”), Asperger’s disorder, and pervasive developmental disorder not otherwise specified (also known as “atypical autism”) according to the Fourth Edition of the Diagnostic and Statistical Manual of Mental Disorders (DSM) issued in 1992 (Autism Awareness Australia, 2018).The DSM was published by the American Psychiatric Association and serves as the primary manual used by clinicians in the U.S., Australia, and many other countries to provide the formal criteria for various diagnoses, including autism (Autism Awareness Australia, 2018).',
#  'Currently, there is no single known cause for autism, however, recent research has identified strong genetic links (Autism Awareness Australia, 2018). We do know though that autism is NOT caused by an individual’s upbringing, their social or economic circumstances, nor is it caused by vaccines or bad parenting! ',
#  'Evidence-based therapy means that there has been some conclusive research to prove the effects of a therapy on its potential users (Autism Awareness Australia, 2018). Whilst many treatments claim to have evidence proving they work, in many cases, there has actually been no extensive top level research done (Autism Awareness Australia, 2018). At Rockmelon, our content is completely evidence-based. All content has been developed with the help of a team of clinicians, parents and experts in the autism field from around the world. ',
#  'If you suspect your child has autism and you do not have a diagnosis yet, don’t wait! Start early intervention. We at Rockmelon believe that as a parent, you know your child best. If you think your child may have a delay or you are in the process of getting a diagnosis there is no harm in getting started early. It is the ‘early’ in early intervention that makes all the difference. If it turns out that your child doesn’t have a developmental delay, many of the skills Rockmelon promotes are applicable to neurotypical children as well.',
#  'There are a number of different therapies available to help assist a child with autism reach their fullest potential.If you are new to the world of autism, you might find yourself floating in a pool of different therapy terms – from occupational therapy to speech pathology, to speech and language therapy to cognitive behaviour therapy. You might also be thinking, which are the ones that your child will need? What if they don’t work? The other thing to note is that something that worked for another family, may not necessarily be of the same benefit for your child. ',
#  'If you suspect your child may have a developmental delay, the best thing you can do is start investigating as soon as possible (Autism Awareness Australia, 2018). If you think your child may have a delay or you are in the process of getting a diagnosis there is no harm in getting started early. It is the ‘early’ in early intervention that makes all the difference. Rockmelon CONNECT+LEARN has been designed to help parents who have a child with additional needs. Children with autism can learn, it is just a matter of teaching a little differently. Rockmelon CONNECT+LEARN provides you with all the \xa0necessary tools and information parents need to help deliver better outcomes for their children.',
#  'Some of the common traits associated with autism are difficulties with communication, social interaction, restricted/repetitive interests and behaviours, behavioural challenges and sensory issues (Autism Awareness Australia, 2018). One child might display all of these, another might display one or two, and another might display none at all. Often, one of the first things parents report noticing is a lack of communication skills. These early signs can present differently in every single child. Remember, some children are just late to talk and it doesn’t immediately mean they have autism. If you are concerned that your child may have a developmental delay, the best thing you can do is get in contact with your family doctor or paediatrician. Don’t wait for a diagnosis to start working with your child to develop some of the skills they may need help with.',
#  'The most common age for parents to first become concerned about autism is around 15-18 months, usually because their toddler’s speech isn’t developing. Children may have speech delay, however, and not have an autism spectrum disorder (ASD). It’s problems with nonverbal social communication that are the real pointers to autism.For example, young children with ASD don’t usually:Their problems may not become obvious until they attend school and social difficulties — such as trouble making friends and acting out in class — start to affect their progress and self-esteem.',
#  'Early intervention is recommended for all children with an autism spectrum disorder. A ‘mild’ case of autism in early childhood can lead to major problems once a child reaches their school and teenage years. Symptoms such as inflexibility and ‘social blindness’ can lead to run ins with teachers and isolation and bullying from peers. Young people on the spectrum are much more likely than their classmates to suffer from anxiety and depression as a result. If a child’s challenges can be targeted early, we are offering them a better chance of negotiating their school years with success.  In fact, research evidence shows that children with milder symptoms respond best to early intervention, with these benefits sustained in the long-term.',
#  'The simple answer is as early as possible. Treatment can commence before a child receives an official diagnosis if autism is strongly suspected. In early childhood, the brain is more ‘plastic’ or able to be changed than at older ages, offering the greatest potential for long-term change. There are now play-based early intervention programs for ASD, such as the Early Start Denver Model, that target toddlers as young as 18 months. Studies show improvements in learning and language as well as reduced symptoms of autism, with these benefits maintained when the children were followed-up two years later.There is research to suggest children progress faster when treatment commences before the age of four, but all young people with ASD, no matter what age, can benefit from science-based interventions.',
#  'Autism spectrum disorder is more common in males, along with a number of other developmental disorders, such as ADHD and learning disabilities. Overall, statistics show that ASD is about 4 times more common among boys than girls. That said, ASD often escapes detection in girls and young women. Girls appear to be more skilled at masking their symptoms, copying the behaviour of friends and classmates and finding ways to fit in. Unfortunately, this often comes at the cost of severe anxiety and depression. It’s not uncommon for girls with ASD not to receive a diagnosis until they reach adulthood. With better recognition of autism in females, there may come a time when the male to female ratio moves closer to 2 or 3 to 1.',
#  'Yes, autism often occurs alongside other conditions, including intellectual disability, seizure disorder (epilepsy), language delay, attention deficit hyperactivity disorder (ADHD) and behaviour disorders such as oppositional defiant disorder, as well as anxiety and genetic disorders such as Fragile X and Down Syndrome. Sometimes these other conditions will have a greater impact on a child’s ability to function at school and home than the autism itself. \xa0Intellectual disability and autism spectrum disorder frequently occur together. A child with ASD and an intellectual disability will have problems with thinking, memory and learning and take longer to learn new skills and behaviours than a child without this diagnosis. With the right support, however, all children can learn. ',
#  'Autism and learning disabilities can occur together, however autism spectrum disorder is not a learning disability. Learning disabilities, also referred to as specific learning disorders, are usually identified once a child is in school and are more commonly associated with ADHD (which also can co-occur with autism). They refer to serious and ongoing problems in one of three areas — reading, writing and mathematics. A well-known learning disorder is dyslexia, which affects reading and spelling and often runs in families. While not all children with ASD will be diagnosed with a specific learning disorder, it’s not uncommon for even very bright children with ASD to have an uneven pattern of skills, where they are gifted at maths but struggle with reading or writing, or vice versa.']

# %%
# Create new dataframe with QA pairs
df2 = pd.DataFrame(zip(quesListUpd,ansListUpd),columns=['Question',link])
df2
# Out:
#                                              Question  \
# 0                                        What is ASD?
# 1                                What are the causes?
# 2                 What are evidence-based therapies?
# 3   I suspect my child has autism, what should I d...
# 4               What therapies are available for ASD?
# 5                How can I help my child with autism?
# 6                 What are the early signs of autism?
# 7   What age do children usually start to show sig...
# 8   Is early intervention necessary in mild cases ...
# 9       How early can you start treatment for autism?
# 10     Is autism a condition that affects only males?
# 11    Does autism often occur with other disorders?
# 12  What is the difference between autism and lear...
#
#                   https://rockmelon.com/about-autism/
# 0   ASD is the acronym for ‘Autism Spectrum Disord...
# 1   Currently, there is no single known cause for ...
# 2   Evidence-based therapy means that there has be...
# 3   If you suspect your child has autism and you d...
# 4   There are a number of different therapies avai...
# 5   If you suspect your child may have a developme...
# 6   Some of the common traits associated with auti...
# 7   The most common age for parents to first becom...
# 8   Early intervention is recommended for all chil...
# 9   The simple answer is as early as possible. Tre...
# 10  Autism spectrum disorder is more common in mal...
# 11  Yes, autism often occurs alongside other condi...
# 12  Autism and learning disabilities can occur tog...

# %%
# Concatenate existing and new dataframes
df3 = pd.concat([df,df2],axis=0)
df3 = df3.sort_values(by=list(df3.columns[1:])).reset_index(drop=True)
df3.head(40)
# Out:
#                                              Question  \
# 0       What are the Autism Spectrum Disorders (ASD)?
# 1                               How common is autism?
# 2                What causes autism? Can it be cured?
# 3                               Is autism contagious?
# 4                     Are rates of autism increasing?
# 5                          Is autism a new condition?
# 6                         Is there a cure for autism?
# 7                            How Is Autism Diagnosed?
# 8                                Is autism permanent?
# 9                              How Is Autism Treated?
# 10                   How common is Asperger syndrome?
# 11               Different names and terms for autism
# 12     The benefits of an Asperger syndrome diagnosis
# 13  How do people with Asperger syndrome see the w...
# 14                 How Asperger syndrome is diagnosed
# 15  How can I find out if my/my child's case is ge...
# 16  How can I be sure vaccines have nothing to do ...
# 17  How can I find out what caused my child's autism?
# 18  How can I help in the search for better treatm...
# 19  What progress has been made so far in autism r...
# 20  If there is no autism epidemic, why do the aut...
# 21  How can I find the best treatments for myself ...
# 22  I think I/my child may have autism but I'm not...
# 23  Can diet help children with autism spectrum di...
# 24          What are the most common signs of autism?
# 25                What are the treatments for autism?
# 26                         Can vaccines cause autism?
# 27  What causes autism spectrum disorder (also kno...
# 28                           Why My Child Has Autism?
# 29                            What is “the Spectrum”?
# 30                                    What is Autism?
# 31            Can My Child with Autism Attend School?
# 32                             What if I Have Autism?
# 33                                       What is ASD?
# 34  What is the difference between autism and lear...
# 35     Is autism a condition that affects only males?
# 36                               What are the causes?
# 37  Is early intervention necessary in mild cases ...
# 38                What are evidence-based therapies?
# 39  I suspect my child has autism, what should I d...
#
#              https://birchtreecenter.org/learn/autism  \
# 0   ASD refers to a wide spectrum of neurodevelopm...
# 1   According to a 2020 report commissioned by the...
# 2   The causes of this complex disorder remain unc...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#    https://www.myautismteam.com/resources/autism-an-overview  \
# 0                                                 NaN
# 1   It is estimated that in the United States 1.6 ...
# 2                                                 NaN
# 3   Autism is not a contagious condition. Autism i...
# 4   Estimates released by the Centers for Disease ...
# 5   It is likely that autism has always existed, b...
# 6   There is no cure for autism. However, early in...
# 7   There is no one single conclusive test for aut...
# 8   There is some controversy on the topic of whet...
# 9   Treatment for autism depends largely on the in...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#    https://www.autism.org.uk/advice-and-guidance/what-is-autism/asperger-syndrome  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  \nAutism, including Asperger syndrome, is much...
# 11  \nOver the years, different diagnostic labels ...
# 12  \nSome people see a formal diagnosis as an unh...
# 13  \nSome people with Asperger syndrome say the w...
# 14  \nThe characteristics of Asperger syndrome var...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#                   https://iancommunity.org/autism-faq  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   There is no blood test to diagnose autism spec...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  If your child has autism and you are intereste...
# 16  Immunizations are a cornerstone of public heal...
# 17  In most individuals it is currently not possib...
# 18  In order for autism research to advance, parti...
# 19  In the past five years, scientists have made s...
# 20  Just days after my live TED talk, the Centers ...
# 21  Research suggests that early intensive behavio...
# 22  The core features of autism are difficulties w...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#    https://icahn.mssm.edu/research/seaver/resources/autism-faqs  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   While there is no medical test for autism, an ...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Autism research is quickly developing across m...
# 20                                                NaN
# 21                                                NaN
# 22  The first step is a conversation with your chi...
# 23  Families have reported improvements in behavio...
# 24  In toddlers, obvious symptoms may not be prese...
# 25  The primary and first-line treatments include ...
# 26  There are several epidemiological studies that...
# 27  There is strong data indicating that genetics ...
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#    https://otsimo.com/en/frequently-asked-questions-autism/  \
# 0                                                 NaN
# 1   According to the U.S. Centers for Disease Cont...
# 2   You may think that something you did or ate or...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  Although mostly there is not one cause that ca...
# 29  Autism is a term that is constantly redefined ...
# 30  Autism spectrum disorder is an umbrella term u...
# 31  Every child has the right to get appropriate e...
# 32  You should consider consulting your doctor for...
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#                   https://rockmelon.com/about-autism/
# 0                                                 NaN
# 1   Recent studies have found that 1 in 59 childre...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   There are a number of different therapies avai...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30  Autism, also known as Autism Spectrum Disorder...
# 31                                                NaN
# 32                                                NaN
# 33  ASD is the acronym for ‘Autism Spectrum Disord...
# 34  Autism and learning disabilities can occur tog...
# 35  Autism spectrum disorder is more common in mal...
# 36  Currently, there is no single known cause for ...
# 37  Early intervention is recommended for all chil...
# 38  Evidence-based therapy means that there has be...
# 39  If you suspect your child has autism and you d...

# %% [markdown]
# ## **Save Output**

# %%
df3.to_excel('ASDquestions8.xlsx',index=False)
