# %% [markdown]
# ## **Import Libraries**

# %%
#!pip install selenium
#!pip install webdriver-manager
#!pip install pyyaml ua-parser user-agents fake-useragent

################ WEB SCRAPING MODULES ############
from selenium import webdriver
from webdriver_manager.firefox import GeckoDriverManager
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.utils import ChromeType
from selenium.webdriver.common.by import By
import bs4
from fake_useragent import UserAgent
import requests
################ TIME MODLULES ###################
import time
from datetime import date 
import datetime
############## DATA MANIPULATION MODULES #########
import os
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords

# %% [markdown]
# ## **Define web source**

# %%
link = 'https://icahn.mssm.edu/research/seaver/resources/autism-faqs'

# %% [markdown]
# ## **Read 100++ questions list**

# %%
df = pd.read_excel('ASDquestions5.xlsx',engine='openpyxl')

df[link]=np.nan
df.head(25)
# Out:
#                                              Question  \
# 0       What are the Autism Spectrum Disorders (ASD)?
# 1                               How common is autism?
# 2                What causes autism? Can it be cured?
# 3                               Is autism contagious?
# 4                     Are rates of autism increasing?
# 5                          Is autism a new condition?
# 6                         Is there a cure for autism?
# 7                            How Is Autism Diagnosed?
# 8                                Is autism permanent?
# 9                              How Is Autism Treated?
# 10                   How common is Asperger syndrome?
# 11               Different names and terms for autism
# 12     The benefits of an Asperger syndrome diagnosis
# 13  How do people with Asperger syndrome see the w...
# 14                 How Asperger syndrome is diagnosed
# 15  How can I find out if my/my child's case is ge...
# 16  How can I be sure vaccines have nothing to do ...
# 17  How can I find out what caused my child's autism?
# 18  How can I help in the search for better treatm...
# 19  What progress has been made so far in autism r...
# 20  If there is no autism epidemic, why do the aut...
# 21  How can I find the best treatments for myself ...
# 22  I think I/my child may have autism but I'm not...
# 23                                    What is Autism?
# 24                       What is Asperger’s Syndrome?
#
#              https://birchtreecenter.org/learn/autism  \
# 0   ASD refers to a wide spectrum of neurodevelopm...
# 1   According to a 2020 report commissioned by the...
# 2   The causes of this complex disorder remain unc...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#    https://www.myautismteam.com/resources/autism-an-overview  \
# 0                                                 NaN
# 1   It is estimated that in the United States 1.6 ...
# 2                                                 NaN
# 3   Autism is not a contagious condition. Autism i...
# 4   Estimates released by the Centers for Disease ...
# 5   It is likely that autism has always existed, b...
# 6   There is no cure for autism. However, early in...
# 7   There is no one single conclusive test for aut...
# 8   There is some controversy on the topic of whet...
# 9   Treatment for autism depends largely on the in...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#    https://www.autism.org.uk/advice-and-guidance/what-is-autism/asperger-syndrome  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  \nAutism, including Asperger syndrome, is much...
# 11  \nOver the years, different diagnostic labels ...
# 12  \nSome people see a formal diagnosis as an unh...
# 13  \nSome people with Asperger syndrome say the w...
# 14  \nThe characteristics of Asperger syndrome var...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#                   https://iancommunity.org/autism-faq  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   There is no blood test to diagnose autism spec...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  If your child has autism and you are intereste...
# 16  Immunizations are a cornerstone of public heal...
# 17  In most individuals it is currently not possib...
# 18  In order for autism research to advance, parti...
# 19  In the past five years, scientists have made s...
# 20  Just days after my live TED talk, the Centers ...
# 21  Research suggests that early intensive behavio...
# 22  The core features of autism are difficulties w...
# 23                                                NaN
# 24                                                NaN
#
#     https://icahn.mssm.edu/research/seaver/resources/autism-faqs
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN

# %% [markdown]
# ## **Scrape QA pairs from website**

# %%
# Open webpage in a new window for scraping
#driver = webdriver.Chrome(ChromeDriverManager(chrome_type=ChromeType.GOOGLE).install())   #cannot fix in colab

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(link)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST driver version for 92.0.4515
# Get LATEST driver version for 92.0.4515
# Trying to download new driver from https://chromedriver.storage.googleapis.com/92.0.4515.107/chromedriver_linux64.zip
# Driver has been saved in cache [/home/aceirus/.wdm/drivers/chromedriver/linux64/92.0.4515.107]

# %%
# Parse text in webpage
source = driver.page_source
soup = bs4.BeautifulSoup(source, 'html.parser')

# %%
# Search the questions mentioned in webpage
quesList = []
for ques in soup.find_all('strong'):
    if(ques.text[-1]=='?'):
        print(ques.text)
        quesList.append(ques.text)
# Out:
# What causes autism spectrum disorder (also known as ASD)?
# Can vaccines cause autism?
# What are the most common signs of autism?
# How is autism diagnosed?
# Can diet help children with autism spectrum disorder?
# What autism research is being done?
# What should I do if I think my child may have autism?
# What are the treatments for autism?

# %%
# Search the answers for corresponding questions in quesList
ansList = []

#for ans in soup.find_all('div', {'class':'field-items'}):
for ans in soup.find_all('p'):

    if ans.find(string=re.compile("autism")):
        #if(ans.text[-1]=='?'):
            toSplit = str(ans)            
            ansSplit = toSplit.split("<br/>")
            ansClean = ansSplit[1].replace("</p>","")

            print(ansClean)
            print('*'*100)
            ansList.append(ansClean)
# Out:
# The experts at the Seaver Autism Center for Research and Treatment have compiled the following answers to frequently asked questions about autism and related conditions.
# ****************************************************************************************************
# There is strong data indicating that genetics are the major cause of autism. However, not all genetic risk is inherited; some genetic changes leading to autism occur as mutations in the egg or sperm.
# ****************************************************************************************************
# There are several epidemiological studies that have disproven the connection between autism and vaccines.
# ****************************************************************************************************
# In toddlers, obvious symptoms may not be present, so it is often the absence of expected behavior that indicates a developmental problem. Autism has two core symptom domains as defined by the Diagnostic and Statistical Manual of Mental Disorders, 5th Edition (DSM-5): The first is deficits in social communication and social interaction, and the second is repetitive and restricted behaviors and interests. The ways in which these symptoms manifest themselves vary from one child to the next. Common symptoms to look for include: fleeting eye contact, limited gesturing such as pointing or waving, limited pretend play, difficulty reading nonverbal cues, odd language such as scripted speech or echolalia (repeating another person’s words), repetitive motor movements, and difficulties with changes in environment or routine.
# ****************************************************************************************************
# While there is no medical test for autism, an autism spectrum diagnosis is made based on observed behavior, developmental history, and autism-specific assessment tools. The “gold standard” assessment includes the Autism Diagnostic Observation Schedule, Second Edition (ADOS-2) and the Autism Diagnostic Interview - Revised (ADI-R). These tools, along with clinical judgment, are used to make a DSM-5 diagnosis of autism spectrum disorder. Early diagnosis is important because it can lead to earlier treatment, which research has linked to more positive outcomes.
# ****************************************************************************************************
# Families have reported improvements in behavior and language as a result of special diets, including elimination diets that remove gluten (a protein in wheat and related grains) and casein (a protein in milk). However, research results do not support the widespread use of elimination diets as a treatment for autism symptoms.
# ****************************************************************************************************
# Autism research is quickly developing across many areas, including genetics, neurobiology, educational interventions, and targeted medications. One promising area of research seeks to identify autism genes in order to develop new medications based on genetic findings.
# ****************************************************************************************************
# The first step is a conversation with your child’s pediatrician. The American Academy of Pediatrics recommends that all children be screened for autism at their 18-month and 24-month well-child checkups. If there are concerns, your pediatrician should refer you to a specialist (such as a child psychiatrist or psychologist, developmental pediatrician, or pediatric neurologist) for a more extensive evaluation. An evaluation conducted by a multidisciplinary team (including a speech therapist, occupational therapist, and physical therapist) may also be beneficial for treatment planning. In addition to an autism-specific evaluation, a hearing test and lead screening should be conducted.
# ****************************************************************************************************
# The primary and first-line treatments include intensive behavioral and educational therapies that promote the development of the unique social and communication deficits seen in individuals with autism. Specific interventions should be tailored to each individual’s needs and may include both behavioral and pharmacological interventions. Many children benefit from a multidisciplinary team that may include applied behavior analysis (ABA) therapists, speech and language pathologists, occupational therapists, physical therapists and other professionals. There is currently no cure for autism.
# ****************************************************************************************************

# %% [markdown]
# ## **Check which questions are similar**

# %%
stop_words = set(stopwords.words('english'))

def clean_text(sent):
    sent = sent.lower() # lowercase
    sent = re.sub(r'[^\w\s]', '', sent) # remove punctuations
    sent = re.sub('Autism Spectrum Disorder','ASD',sent) # Compress term
    sent = [w for w in sent.split() if not w.lower() in stop_words] # Remove stopwords
    sent = " ".join(sent)
    return sent

# %%
def jaccard_similarity(list1, list2):
    s1 = set(list1)
    s2 = set(list2)
    return float(len(s1.intersection(s2)) / len(s1.union(s2)))

# %%
# try to match websource questions with our own 100 questions list
for c1,i in enumerate(quesList):
    i2 = clean_text(i)
    list1 = i2.split()
    
    temp1 = 0.0
    temp2 = ''
    temp3 = ''
    temp4 = 0
    
    for c2,j in enumerate(df['Question']):
        j2 = clean_text(j)
        list2 = j2.split()
            
        sim = jaccard_similarity(list1, list2)
        if(sim>temp1):
            temp1 = sim
            temp2 = j
            temp3 = i
            temp4 = c2
            
    if(temp1>=0.3):  # sim threshold
        print('Website --> ',temp3,'(Index {})'.format(c1))
        print('100 questions list --> ',temp2,'(Index {})'.format(temp4))
        print('similarity:', temp1)
        print('*'*100)
# Out:
# Website -->  What causes autism spectrum disorder (also known as ASD)? (Index 0)
# 100 questions list -->  What are the Autism Spectrum Disorders (ASD)? (Index 0)
# similarity: 0.375
# ****************************************************************************************************
# Website -->  Can vaccines cause autism? (Index 1)
# 100 questions list -->  Does Thimerosal cause autism? (Index 48)
# similarity: 0.5
# ****************************************************************************************************
# Website -->  What are the most common signs of autism? (Index 2)
# 100 questions list -->  How common is autism? (Index 1)
# similarity: 0.6666666666666666
# ****************************************************************************************************
# Website -->  How is autism diagnosed? (Index 3)
# 100 questions list -->  How Is Autism Diagnosed? (Index 7)
# similarity: 1.0
# ****************************************************************************************************
# Website -->  What autism research is being done? (Index 5)
# 100 questions list -->  What progress has been made so far in autism research? (Index 19)
# similarity: 0.3333333333333333
# ****************************************************************************************************
# Website -->  What should I do if I think my child may have autism? (Index 6)
# 100 questions list -->  I think I/my child may have autism but I'm not sure. How can I find out? (Index 22)
# similarity: 0.5
# ****************************************************************************************************
# Website -->  What are the treatments for autism? (Index 7)
# 100 questions list -->  What is Autism? (Index 23)
# similarity: 0.5
# ****************************************************************************************************

# %%
for i in range (0,len(quesList)):
    print("Index #{0:d}: {1:s}".format(i,quesList[i]))
# Out:
# Index #0: What causes autism spectrum disorder (also known as ASD)?
# Index #1: Can vaccines cause autism?
# Index #2: What are the most common signs of autism?
# Index #3: How is autism diagnosed?
# Index #4: Can diet help children with autism spectrum disorder?
# Index #5: What autism research is being done?
# Index #6: What should I do if I think my child may have autism?
# Index #7: What are the treatments for autism?

# %%
for i in range (0,len(ansList)):
    print("Index #{0:d}: {1:s}".format(i,ansList[i]))
# Out:
# Index #0: The experts at the Seaver Autism Center for Research and Treatment have compiled the following answers to frequently asked questions about autism and related conditions.
# Index #1: There is strong data indicating that genetics are the major cause of autism. However, not all genetic risk is inherited; some genetic changes leading to autism occur as mutations in the egg or sperm.
# Index #2: There are several epidemiological studies that have disproven the connection between autism and vaccines.
# Index #3: In toddlers, obvious symptoms may not be present, so it is often the absence of expected behavior that indicates a developmental problem. Autism has two core symptom domains as defined by the Diagnostic and Statistical Manual of Mental Disorders, 5th Edition (DSM-5): The first is deficits in social communication and social interaction, and the second is repetitive and restricted behaviors and interests. The ways in which these symptoms manifest themselves vary from one child to the next. Common symptoms to look for include: fleeting eye contact, limited gesturing such as pointing or waving, limited pretend play, difficulty reading nonverbal cues, odd language such as scripted speech or echolalia (repeating another person’s words), repetitive motor movements, and difficulties with changes in environment or routine.
# Index #4: While there is no medical test for autism, an autism spectrum diagnosis is made based on observed behavior, developmental history, and autism-specific assessment tools. The “gold standard” assessment includes the Autism Diagnostic Observation Schedule, Second Edition (ADOS-2) and the Autism Diagnostic Interview - Revised (ADI-R). These tools, along with clinical judgment, are used to make a DSM-5 diagnosis of autism spectrum disorder. Early diagnosis is important because it can lead to earlier treatment, which research has linked to more positive outcomes.
# Index #5: Families have reported improvements in behavior and language as a result of special diets, including elimination diets that remove gluten (a protein in wheat and related grains) and casein (a protein in milk). However, research results do not support the widespread use of elimination diets as a treatment for autism symptoms.
# Index #6: Autism research is quickly developing across many areas, including genetics, neurobiology, educational interventions, and targeted medications. One promising area of research seeks to identify autism genes in order to develop new medications based on genetic findings.
# Index #7: The first step is a conversation with your child’s pediatrician. The American Academy of Pediatrics recommends that all children be screened for autism at their 18-month and 24-month well-child checkups. If there are concerns, your pediatrician should refer you to a specialist (such as a child psychiatrist or psychologist, developmental pediatrician, or pediatric neurologist) for a more extensive evaluation. An evaluation conducted by a multidisciplinary team (including a speech therapist, occupational therapist, and physical therapist) may also be beneficial for treatment planning. In addition to an autism-specific evaluation, a hearing test and lead screening should be conducted.
# Index #8: The primary and first-line treatments include intensive behavioral and educational therapies that promote the development of the unique social and communication deficits seen in individuals with autism. Specific interventions should be tailored to each individual’s needs and may include both behavioral and pharmacological interventions. Many children benefit from a multidisciplinary team that may include applied behavior analysis (ABA) therapists, speech and language pathologists, occupational therapists, physical therapists and other professionals. There is currently no cure for autism.

# %%
# add websource answer to matched question in existing dataframe
df[link].loc[7]=ansList[4] #3
df[link].loc[19]=ansList[6] #5
df[link].loc[22]=ansList[7] #6

# %%
df[link].loc[7]
# Out:
# 'While there is no medical test for autism, an autism spectrum diagnosis is made based on observed behavior, developmental history, and autism-specific assessment tools. The “gold standard” assessment includes the Autism Diagnostic Observation Schedule, Second Edition (ADOS-2) and the Autism Diagnostic Interview - Revised (ADI-R). These tools, along with clinical judgment, are used to make a DSM-5 diagnosis of autism spectrum disorder. Early diagnosis is important because it can lead to earlier treatment, which research has linked to more positive outcomes.'

# %%
# update with new valid questions list
quesListUpd = [quesList[0],
               quesList[1],
               quesList[2],
               quesList[4],
               quesList[7]]

quesListUpd
# Out:
# ['What causes autism spectrum disorder (also known as ASD)?',
#  'Can vaccines cause autism?',
#  'What are the most common signs of autism?',
#  'Can diet help children with autism spectrum disorder?',
#  'What are the treatments for autism?']

# %%
# manually select answers to updated questions list
ansListUpd = [ansList[1],
              ansList[2],
              ansList[3],
              ansList[5],
              ansList[8]]

ansListUpd
# Out:
# ['There is strong data indicating that genetics are the major cause of autism. However, not all genetic risk is inherited; some genetic changes leading to autism occur as mutations in the egg or sperm.',
#  'There are several epidemiological studies that have disproven the connection between autism and vaccines.',
#  'In toddlers, obvious symptoms may not be present, so it is often the absence of expected behavior that indicates a developmental problem. Autism has two core symptom domains as defined by the Diagnostic and Statistical Manual of Mental Disorders, 5th Edition (DSM-5): The first is deficits in social communication and social interaction, and the second is repetitive and restricted behaviors and interests. The ways in which these symptoms manifest themselves vary from one child to the next. Common symptoms to look for include: fleeting eye contact, limited gesturing such as pointing or waving, limited pretend play, difficulty reading nonverbal cues, odd language such as scripted speech or echolalia (repeating another person’s words), repetitive motor movements, and difficulties with changes in environment or routine.',
#  'Families have reported improvements in behavior and language as a result of special diets, including elimination diets that remove gluten (a protein in wheat and related grains) and casein (a protein in milk). However, research results do not support the widespread use of elimination diets as a treatment for autism symptoms.',
#  'The primary and first-line treatments include intensive behavioral and educational therapies that promote the development of the unique social and communication deficits seen in individuals with autism. Specific interventions should be tailored to each individual’s needs and may include both behavioral and pharmacological interventions. Many children benefit from a multidisciplinary team that may include applied behavior analysis (ABA) therapists, speech and language pathologists, occupational therapists, physical therapists and other professionals. There is currently no cure for autism.']

# %%
# Create new dataframe with QA pairs
df2 = pd.DataFrame(zip(quesListUpd,ansListUpd),columns=['Question',link])
df2
# Out:
#                                             Question  \
# 0  What causes autism spectrum disorder (also kno...
# 1                         Can vaccines cause autism?
# 2          What are the most common signs of autism?
# 3  Can diet help children with autism spectrum di...
# 4                What are the treatments for autism?
#
#   https://icahn.mssm.edu/research/seaver/resources/autism-faqs
# 0  There is strong data indicating that genetics ...
# 1  There are several epidemiological studies that...
# 2  In toddlers, obvious symptoms may not be prese...
# 3  Families have reported improvements in behavio...
# 4  The primary and first-line treatments include ...

# %%
# Concatenate existing and new dataframes
df3 = pd.concat([df,df2],axis=0)
df3 = df3.sort_values(by=list(df3.columns[1:])).reset_index(drop=True)
df3.head(40)
# Out:
#                                              Question  \
# 0       What are the Autism Spectrum Disorders (ASD)?
# 1                               How common is autism?
# 2                What causes autism? Can it be cured?
# 3                               Is autism contagious?
# 4                     Are rates of autism increasing?
# 5                          Is autism a new condition?
# 6                         Is there a cure for autism?
# 7                            How Is Autism Diagnosed?
# 8                                Is autism permanent?
# 9                              How Is Autism Treated?
# 10                   How common is Asperger syndrome?
# 11               Different names and terms for autism
# 12     The benefits of an Asperger syndrome diagnosis
# 13  How do people with Asperger syndrome see the w...
# 14                 How Asperger syndrome is diagnosed
# 15  How can I find out if my/my child's case is ge...
# 16  How can I be sure vaccines have nothing to do ...
# 17  How can I find out what caused my child's autism?
# 18  How can I help in the search for better treatm...
# 19  What progress has been made so far in autism r...
# 20  If there is no autism epidemic, why do the aut...
# 21  How can I find the best treatments for myself ...
# 22  I think I/my child may have autism but I'm not...
# 23  Can diet help children with autism spectrum di...
# 24          What are the most common signs of autism?
# 25                What are the treatments for autism?
# 26                         Can vaccines cause autism?
# 27  What causes autism spectrum disorder (also kno...
# 28                                    What is Autism?
# 29                       What is Asperger’s Syndrome?
# 30  How can you tell Autism from Asperger’s Syndrome?
# 31  What is Pervasive Developmental Disorder – Not...
# 32                             What is Rett Syndrome?
# 33         What is Childhood Disintegrative Disorder?
# 34     What is the prognosis of children with Autism?
# 35  Are there other diseases that have the same sy...
# 36  Do autistic children commonly suffer from othe...
# 37  Is there an association between autism and Tou...
# 38  I have heard that the symptoms of autism are e...
# 39                 Are there risk factors for Autism?
#
#              https://birchtreecenter.org/learn/autism  \
# 0   ASD refers to a wide spectrum of neurodevelopm...
# 1   According to a 2020 report commissioned by the...
# 2   The causes of this complex disorder remain unc...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#    https://www.myautismteam.com/resources/autism-an-overview  \
# 0                                                 NaN
# 1   It is estimated that in the United States 1.6 ...
# 2                                                 NaN
# 3   Autism is not a contagious condition. Autism i...
# 4   Estimates released by the Centers for Disease ...
# 5   It is likely that autism has always existed, b...
# 6   There is no cure for autism. However, early in...
# 7   There is no one single conclusive test for aut...
# 8   There is some controversy on the topic of whet...
# 9   Treatment for autism depends largely on the in...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#    https://www.autism.org.uk/advice-and-guidance/what-is-autism/asperger-syndrome  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  \nAutism, including Asperger syndrome, is much...
# 11  \nOver the years, different diagnostic labels ...
# 12  \nSome people see a formal diagnosis as an unh...
# 13  \nSome people with Asperger syndrome say the w...
# 14  \nThe characteristics of Asperger syndrome var...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#                   https://iancommunity.org/autism-faq  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   There is no blood test to diagnose autism spec...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  If your child has autism and you are intereste...
# 16  Immunizations are a cornerstone of public heal...
# 17  In most individuals it is currently not possib...
# 18  In order for autism research to advance, parti...
# 19  In the past five years, scientists have made s...
# 20  Just days after my live TED talk, the Centers ...
# 21  Research suggests that early intensive behavio...
# 22  The core features of autism are difficulties w...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
#
#    https://icahn.mssm.edu/research/seaver/resources/autism-faqs
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   While there is no medical test for autism, an ...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Autism research is quickly developing across m...
# 20                                                NaN
# 21                                                NaN
# 22  The first step is a conversation with your chi...
# 23  Families have reported improvements in behavio...
# 24  In toddlers, obvious symptoms may not be prese...
# 25  The primary and first-line treatments include ...
# 26  There are several epidemiological studies that...
# 27  There is strong data indicating that genetics ...
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN

# %% [markdown]
# ## **Save Output**

# %%
df3.to_excel('ASDquestions6.xlsx',index=False)
