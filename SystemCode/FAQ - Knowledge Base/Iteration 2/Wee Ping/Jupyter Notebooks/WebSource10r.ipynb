# %% [markdown]
# ## **Import Libraries**

# %%
#!pip install selenium
#!pip install webdriver-manager
#!pip install pyyaml ua-parser user-agents fake-useragent

################ WEB SCRAPING MODULES ############
from selenium import webdriver
from webdriver_manager.firefox import GeckoDriverManager
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.utils import ChromeType
from selenium.webdriver.common.by import By
import bs4
from fake_useragent import UserAgent
import requests
################ TIME MODLULES ###################
import time
from datetime import date 
import datetime
############## DATA MANIPULATION MODULES #########
import os
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords

# %% [markdown]
# ## **Define web source**

# %%
link = 'https://www.autism.org.sg/living-with-autism/what-is-autism'

# %% [markdown]
# ## **Read 100++ questions list**

# %%
df = pd.read_excel('ASDquestions3r.xlsx',engine='openpyxl')

df[link]=np.nan
df.head(55)
# Out:
#                                              Question  \
# 0       What are the Autism Spectrum Disorders (ASD)?
# 1                               How common is autism?
# 2                What causes autism? Can it be cured?
# 3                               Is autism contagious?
# 4                     Are rates of autism increasing?
# 5                          Is autism a new condition?
# 6                         Is there a cure for autism?
# 7                            How Is Autism Diagnosed?
# 8                                Is autism permanent?
# 9                              How Is Autism Treated?
# 10                   How common is Asperger syndrome?
# 11               Different names and terms for autism
# 12     The benefits of an Asperger syndrome diagnosis
# 13  How do people with Asperger syndrome see the w...
# 14                 How Asperger syndrome is diagnosed
# 15  How can I find out if my/my child's case is ge...
# 16  How can I be sure vaccines have nothing to do ...
# 17  How can I find out what caused my child's autism?
# 18  How can I help in the search for better treatm...
# 19  What progress has been made so far in autism r...
# 20  If there is no autism epidemic, why do the aut...
# 21  How can I find the best treatments for myself ...
# 22  I think I/my child may have autism but I'm not...
# 23  Can diet help children with autism spectrum di...
# 24          What are the most common signs of autism?
# 25                What are the treatments for autism?
# 26                         Can vaccines cause autism?
# 27  What causes autism spectrum disorder (also kno...
# 28                           Why My Child Has Autism?
# 29                            What is “the Spectrum”?
# 30                                    What is Autism?
# 31            Can My Child with Autism Attend School?
# 32                             What if I Have Autism?
# 33                                       What is ASD?
# 34  What is the difference between autism and lear...
# 35     Is autism a condition that affects only males?
# 36                               What are the causes?
# 37  Is early intervention necessary in mild cases ...
# 38                What are evidence-based therapies?
# 39  I suspect my child has autism, what should I d...
# 40               How can I help my child with autism?
# 41                What are the early signs of autism?
# 42  What age do children usually start to show sig...
# 43      How early can you start treatment for autism?
# 44              What therapies are available for ASD?
# 45     Can I wait to have my child tested for Autism?
# 46    Does autism often occur with other disorders?
# 47                 Do autistic people look different?
# 48              Secondary conditions and difficulties
# 49         Autistic people with complex support needs
# 50                               Talking about autism
# 51                       What is Asperger’s Syndrome?
# 52  How can you tell Autism from Asperger’s Syndrome?
# 53  What is Pervasive Developmental Disorder – Not...
# 54                             What is Rett Syndrome?
#
#              https://birchtreecenter.org/learn/autism  \
# 0   ASD refers to a wide spectrum of neurodevelopm...
# 1   According to a 2020 report commissioned by the...
# 2   The causes of this complex disorder remain unc...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#    https://www.myautismteam.com/resources/autism-an-overview  \
# 0                                                 NaN
# 1   It is estimated that in the United States 1.6 ...
# 2                                                 NaN
# 3   Autism is not a contagious condition. Autism i...
# 4   Estimates released by the Centers for Disease ...
# 5   It is likely that autism has always existed, b...
# 6   There is no cure for autism. However, early in...
# 7   There is no one single conclusive test for aut...
# 8   There is some controversy on the topic of whet...
# 9   Treatment for autism depends largely on the in...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#    https://www.autism.org.uk/advice-and-guidance/what-is-autism/asperger-syndrome  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  \nAutism, including Asperger syndrome, is much...
# 11  \nOver the years, different diagnostic labels ...
# 12  \nSome people see a formal diagnosis as an unh...
# 13  \nSome people with Asperger syndrome say the w...
# 14  \nThe characteristics of Asperger syndrome var...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#                   https://iancommunity.org/autism-faq  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   There is no blood test to diagnose autism spec...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  If your child has autism and you are intereste...
# 16  Immunizations are a cornerstone of public heal...
# 17  In most individuals it is currently not possib...
# 18  In order for autism research to advance, parti...
# 19  In the past five years, scientists have made s...
# 20  Just days after my live TED talk, the Centers ...
# 21  Research suggests that early intensive behavio...
# 22  The core features of autism are difficulties w...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#    https://icahn.mssm.edu/research/seaver/resources/autism-faqs  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   While there is no medical test for autism, an ...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Autism research is quickly developing across m...
# 20                                                NaN
# 21                                                NaN
# 22  The first step is a conversation with your chi...
# 23  Families have reported improvements in behavio...
# 24  In toddlers, obvious symptoms may not be prese...
# 25  The primary and first-line treatments include ...
# 26  There are several epidemiological studies that...
# 27  There is strong data indicating that genetics ...
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#    https://otsimo.com/en/frequently-asked-questions-autism/  \
# 0                                                 NaN
# 1   According to the U.S. Centers for Disease Cont...
# 2   You may think that something you did or ate or...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  Although mostly there is not one cause that ca...
# 29  Autism is a term that is constantly redefined ...
# 30  Autism spectrum disorder is an umbrella term u...
# 31  Every child has the right to get appropriate e...
# 32  You should consider consulting your doctor for...
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#                   https://rockmelon.com/about-autism/  \
# 0                                                 NaN
# 1   Recent studies have found that 1 in 59 childre...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   There are a number of different therapies avai...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30  Autism, also known as Autism Spectrum Disorder...
# 31                                                NaN
# 32                                                NaN
# 33  ASD is the acronym for ‘Autism Spectrum Disord...
# 34  Autism and learning disabilities can occur tog...
# 35  Autism spectrum disorder is more common in mal...
# 36  Currently, there is no single known cause for ...
# 37  Early intervention is recommended for all chil...
# 38  Evidence-based therapy means that there has be...
# 39  If you suspect your child has autism and you d...
# 40  If you suspect your child may have a developme...
# 41  Some of the common traits associated with auti...
# 42  The most common age for parents to first becom...
# 43  The simple answer is as early as possible. Tre...
# 44  There are a number of different therapies avai...
# 45  There are scientifically validated tests, such...
# 46  Yes, autism often occurs alongside other condi...
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#    https://www.amaze.org.au/understand-autism/about-autism/  \
# 0                                                 NaN
# 1                                                 NaN
# 2   There is no known cause of autism.Much researc...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47  Autism is a neurodevelopmental (meaning relate...
# 48  Autism may be present with other conditions. T...
# 49  Autistic people with complex support needs are...
# 50  The language we useis powerful, because it hel...
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#    https://autismrecovery.sg/autism/what-is-aspergers/  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51  For a person with Asperger's syndrome, reading...
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#     https://www.autism.org.sg/living-with-autism/what-is-autism
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN

# %% [markdown]
# ## **Scrape QA pairs from website**

# %%
# Open webpage in a new window for scraping
#driver = webdriver.Chrome(ChromeDriverManager(chrome_type=ChromeType.GOOGLE).install())   #cannot fix in colab

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(link)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST driver version for 92.0.4515
# Driver [/home/aceirus/.wdm/drivers/chromedriver/linux64/92.0.4515.107/chromedriver] found in cache

# %%
# Parse text in webpage
source = driver.page_source
soup = bs4.BeautifulSoup(source, 'html.parser')

# %%
# Search the questions mentioned in webpage
quesList = []
for ques in soup.find_all('h4'):
#for ques in soup.find_all('button',{'class':'btn btn-unstyled'}):

    if(ques.text[-1]=='?'):
        #toSplit = str(ques.text)
        #quesSplit = toSplit.split()
        #quesJoin = ' '.join(quesSplit)
        
        print(ques.text)
        quesList.append(ques.text)
# Out:
# What is autism?
# What causes autism?
# What is Asperger’s Syndrome (DSM IV)?
# How are people of different degrees of autism understood?
# Is there a cure for autism? Will my child grow out of autism?

# %%
# Search the answers for corresponding questions in quesList
ansList = []

#for ans in soup.find_all('div',{'class':'content-header'}):
for ans in soup.find_all('p'):

    #if ans.find(string=re.compile("autism")):
            #toSplit = str(ans.text)            
            #ansSplit = toSplit.split("<br/>")
            #ansClean = toSplit.replace("\n","")
            
            print(ans.text)
            print('*'*100)
            ansList.append(ans.text)
# Out:
# Autism is a lifelong developmental disability that affects a person’s ability to make sense of the world and relate with others. Autism comes from ‘autos’, the Greek word for ‘self’, and a person on the autism spectrum is often referred to as someone who lives in a world of his own.
# ****************************************************************************************************
# Although there are many theories, no one fully knows the definitive answer to this question. Research shows that autism can be caused by a variety of conditions that affect brain development, which may occur before, during or after birth.
# ****************************************************************************************************
# While the cause or combination of causes of autism is not fully understood, research suggests a biological correlation affecting the parts of the brain that process language and information coming in from the senses. Other research findings suggest that there may be an imbalance in certain chemicals in the brain. Genetic factors may sometimes be involved in certain families. In reality, what we know is that autism may develop from a combination of several “causes”.
# ****************************************************************************************************
# Asperger’s Syndrome is a form of autism, a condition that affects the way a person makes sense of the world and relates to others. A number of traits of autism are common to Asperger’s Syndrome including: difficulties in communicating, social relationships, and a lack of social imagination and creative play.
# ****************************************************************************************************
# Persons with Asperger’s Syndrome usually have fewer difficulties with language than those with classical autism, often speaking fluently, though their words can sometimes sound formal or ‘unusual’ to the listener. Even though they have few difficulties with language, they do have significant difficulties with social aspects of communication.
# ****************************************************************************************************
# Many children with Asperger’s Syndrome are able to adapt to learning in a mainstream school setting. With the right support and encouragement, they are able to make good progress and go on to further education and employment options.
# ****************************************************************************************************
# Autism is known as a spectrum condition as no two persons diagnosed with autism are the same. They may differ in the interaction of 2 key dimensions:
# ****************************************************************************************************
# Any person with autism may have differing degrees of autism as well as intellectual abilities. This helps us understand that any combination may exist and we must not make assumptions that high autism always implies low ability or vice versa.
# ****************************************************************************************************
# Every person with autism is to be understood so that we can find the best way to support them and help them better adapt to the community.
# ****************************************************************************************************
#
# ****************************************************************************************************
# Autism is a life-long developmental condition. There is currently no known “cure” for autism. Children do not ‘outgrow’ autism but symptoms may lessen with intervention. Structured intervention and training will help the individuals acquire skills, but not cure the condition. There is a wide body of research to support the knowledge that young children experience significant improvements when intervention is started at the earliest possible age.
# ****************************************************************************************************
# The learning curve for the preschooler with autism is different from his/her peers. Children often require explicit instruction and practice of the core missing skills in autism in the areas of social interaction, communication, self-regulation and organisational skills. in order to be more independent learners.
# ****************************************************************************************************
# Autism Resource Centre (Singapore) or ARC(S) is a not-for-profit charity based in Singapore officially registered in year 2000. It was started by a group of professionals and parent volunteers dedicated to serving children and adults on the autism spectrum to help these individuals lead meaningful and independent lives in society.
# ****************************************************************************************************
#
# ****************************************************************************************************
#   5, Ang Mo Kio Avenue 10, Singapore 569739
# ****************************************************************************************************
#   +65 6323 3258
# ****************************************************************************************************
#   +65 6323 1974
# ****************************************************************************************************
#
# ****************************************************************************************************
# Supported by the following organisations and other donors:
# ****************************************************************************************************

# %% [markdown]
# ## **Check which questions are similar**

# %%
stop_words = set(stopwords.words('english'))

def clean_text(sent):
    sent = sent.lower() # lowercase
    sent = re.sub(r'[^\w\s]', '', sent) # remove punctuations
    sent = re.sub('Autism Spectrum Disorder','ASD',sent) # Compress term
    sent = [w for w in sent.split() if not w.lower() in stop_words] # Remove stopwords
    sent = " ".join(sent)
    return sent

# %%
def jaccard_similarity(list1, list2):
    s1 = set(list1)
    s2 = set(list2)
    return float(len(s1.intersection(s2)) / len(s1.union(s2)))

# %%
# try to match websource questions with our own 100 questions list
for c1,i in enumerate(quesList):
    i2 = clean_text(i)
    list1 = i2.split()
    
    temp1 = 0.0
    temp2 = ''
    temp3 = ''
    temp4 = 0
    
    for c2,j in enumerate(df['Question']):
        j2 = clean_text(j)
        list2 = j2.split()
            
        sim = jaccard_similarity(list1, list2)
        if(sim>temp1):
            temp1 = sim
            temp2 = j
            temp3 = i
            temp4 = c2
            
    if(temp1>=0.3):  # sim threshold
        print('Website --> ',temp3,'(Index {})'.format(c1))
        print('100 questions list --> ',temp2,'(Index {})'.format(temp4))
        print('similarity:', temp1)
        print('*'*100)
# Out:
# Website -->  What is autism? (Index 0)
# 100 questions list -->  What is Autism? (Index 30)
# similarity: 1.0
# ****************************************************************************************************
# Website -->  What causes autism? (Index 1)
# 100 questions list -->  What causes autism? Can it be cured? (Index 2)
# similarity: 0.6666666666666666
# ****************************************************************************************************
# Website -->  What is Asperger’s Syndrome (DSM IV)? (Index 2)
# 100 questions list -->  What is Asperger’s Syndrome? (Index 51)
# similarity: 0.5
# ****************************************************************************************************
# Website -->  Is there a cure for autism? Will my child grow out of autism? (Index 4)
# 100 questions list -->  Is there a cure for autism? (Index 6)
# similarity: 0.5
# ****************************************************************************************************

# %%
for i in range (0,len(quesList)):
    print("Index #{0:d}: {1:s}".format(i,quesList[i]))
# Out:
# Index #0: What is autism?
# Index #1: What causes autism?
# Index #2: What is Asperger’s Syndrome (DSM IV)?
# Index #3: How are people of different degrees of autism understood?
# Index #4: Is there a cure for autism? Will my child grow out of autism?

# %%
for i in range (0,len(ansList)):
    print("Index #{0:d}: {1:s}".format(i,ansList[i]))
# Out:
# Index #0: Autism is a lifelong developmental disability that affects a person’s ability to make sense of the world and relate with others. Autism comes from ‘autos’, the Greek word for ‘self’, and a person on the autism spectrum is often referred to as someone who lives in a world of his own.
# Index #1: Although there are many theories, no one fully knows the definitive answer to this question. Research shows that autism can be caused by a variety of conditions that affect brain development, which may occur before, during or after birth.
# Index #2: While the cause or combination of causes of autism is not fully understood, research suggests a biological correlation affecting the parts of the brain that process language and information coming in from the senses. Other research findings suggest that there may be an imbalance in certain chemicals in the brain. Genetic factors may sometimes be involved in certain families. In reality, what we know is that autism may develop from a combination of several “causes”.
# Index #3: Asperger’s Syndrome is a form of autism, a condition that affects the way a person makes sense of the world and relates to others. A number of traits of autism are common to Asperger’s Syndrome including: difficulties in communicating, social relationships, and a lack of social imagination and creative play.
# Index #4: Persons with Asperger’s Syndrome usually have fewer difficulties with language than those with classical autism, often speaking fluently, though their words can sometimes sound formal or ‘unusual’ to the listener. Even though they have few difficulties with language, they do have significant difficulties with social aspects of communication.
# Index #5: Many children with Asperger’s Syndrome are able to adapt to learning in a mainstream school setting. With the right support and encouragement, they are able to make good progress and go on to further education and employment options.
# Index #6: Autism is known as a spectrum condition as no two persons diagnosed with autism are the same. They may differ in the interaction of 2 key dimensions:
# Index #7: Any person with autism may have differing degrees of autism as well as intellectual abilities. This helps us understand that any combination may exist and we must not make assumptions that high autism always implies low ability or vice versa.
# Index #8: Every person with autism is to be understood so that we can find the best way to support them and help them better adapt to the community.
# Index #9:
# Index #10: Autism is a life-long developmental condition. There is currently no known “cure” for autism. Children do not ‘outgrow’ autism but symptoms may lessen with intervention. Structured intervention and training will help the individuals acquire skills, but not cure the condition. There is a wide body of research to support the knowledge that young children experience significant improvements when intervention is started at the earliest possible age.
# Index #11: The learning curve for the preschooler with autism is different from his/her peers. Children often require explicit instruction and practice of the core missing skills in autism in the areas of social interaction, communication, self-regulation and organisational skills. in order to be more independent learners.
# Index #12: Autism Resource Centre (Singapore) or ARC(S) is a not-for-profit charity based in Singapore officially registered in year 2000. It was started by a group of professionals and parent volunteers dedicated to serving children and adults on the autism spectrum to help these individuals lead meaningful and independent lives in society.
# Index #13:
# Index #14:   5, Ang Mo Kio Avenue 10, Singapore 569739
# Index #15:   +65 6323 3258
# Index #16:   +65 6323 1974
# Index #17:
# Index #18: Supported by the following organisations and other donors:

# %%
# add websource answer to matched question in existing dataframe
df[link].loc[30]=ansList[0] #0
df[link].loc[2]=ansList[1]+ansList[2] #1
df[link].loc[51]=ansList[3]+ansList[4]+ansList[5] #2
df[link].loc[6]=ansList[1]+ansList[2] #4

# %%
df[link].loc[30]
# Out:
# 'Autism is a lifelong developmental disability that affects a person’s ability to make sense of the world and relate with others. Autism comes from ‘autos’, the Greek word for ‘self’, and a person on the autism spectrum is often referred to as someone who lives in a world of his own.'

# %%
# update with new valid questions list
quesListUpd = [quesList[3]]

quesListUpd
# Out:
# ['How are people of different degrees of autism understood?']

# %%
# manually select answers to updated questions list
ansListUpd = [ansList[6]+ansList[7]+ansList[8]]

ansListUpd
# Out:
# ['Autism is known as a spectrum condition as no two persons diagnosed with autism are the same. They may differ in the interaction of 2 key dimensions:Any person with autism may have differing degrees of autism as well as intellectual abilities. This helps us understand that any combination may exist and we must not make assumptions that high autism always implies low ability or vice versa.Every person with autism is to be understood so that we can find the best way to support them and help them better adapt to the community.']

# %%
# Create new dataframe with QA pairs
df2 = pd.DataFrame(zip(quesListUpd,ansListUpd),columns=['Question',link])
df2
# Out:
#                                             Question  \
# 0  How are people of different degrees of autism ...
#
#   https://www.autism.org.sg/living-with-autism/what-is-autism
# 0  Autism is known as a spectrum condition as no ...

# %%
# Concatenate existing and new dataframes
df3 = pd.concat([df,df2],axis=0)
df3 = df3.sort_values(by=list(df3.columns[1:])).reset_index(drop=True)
df3.head(55)
# Out:
#                                              Question  \
# 0       What are the Autism Spectrum Disorders (ASD)?
# 1                               How common is autism?
# 2                What causes autism? Can it be cured?
# 3                               Is autism contagious?
# 4                     Are rates of autism increasing?
# 5                          Is autism a new condition?
# 6                         Is there a cure for autism?
# 7                            How Is Autism Diagnosed?
# 8                                Is autism permanent?
# 9                              How Is Autism Treated?
# 10                   How common is Asperger syndrome?
# 11               Different names and terms for autism
# 12     The benefits of an Asperger syndrome diagnosis
# 13  How do people with Asperger syndrome see the w...
# 14                 How Asperger syndrome is diagnosed
# 15  How can I find out if my/my child's case is ge...
# 16  How can I be sure vaccines have nothing to do ...
# 17  How can I find out what caused my child's autism?
# 18  How can I help in the search for better treatm...
# 19  What progress has been made so far in autism r...
# 20  If there is no autism epidemic, why do the aut...
# 21  How can I find the best treatments for myself ...
# 22  I think I/my child may have autism but I'm not...
# 23  Can diet help children with autism spectrum di...
# 24          What are the most common signs of autism?
# 25                What are the treatments for autism?
# 26                         Can vaccines cause autism?
# 27  What causes autism spectrum disorder (also kno...
# 28                           Why My Child Has Autism?
# 29                            What is “the Spectrum”?
# 30                                    What is Autism?
# 31            Can My Child with Autism Attend School?
# 32                             What if I Have Autism?
# 33                                       What is ASD?
# 34  What is the difference between autism and lear...
# 35     Is autism a condition that affects only males?
# 36                               What are the causes?
# 37  Is early intervention necessary in mild cases ...
# 38                What are evidence-based therapies?
# 39  I suspect my child has autism, what should I d...
# 40               How can I help my child with autism?
# 41                What are the early signs of autism?
# 42  What age do children usually start to show sig...
# 43      How early can you start treatment for autism?
# 44              What therapies are available for ASD?
# 45     Can I wait to have my child tested for Autism?
# 46    Does autism often occur with other disorders?
# 47                 Do autistic people look different?
# 48              Secondary conditions and difficulties
# 49         Autistic people with complex support needs
# 50                               Talking about autism
# 51                       What is Asperger’s Syndrome?
# 52  How are people of different degrees of autism ...
# 53  How can you tell Autism from Asperger’s Syndrome?
# 54  What is Pervasive Developmental Disorder – Not...
#
#              https://birchtreecenter.org/learn/autism  \
# 0   ASD refers to a wide spectrum of neurodevelopm...
# 1   According to a 2020 report commissioned by the...
# 2   The causes of this complex disorder remain unc...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#    https://www.myautismteam.com/resources/autism-an-overview  \
# 0                                                 NaN
# 1   It is estimated that in the United States 1.6 ...
# 2                                                 NaN
# 3   Autism is not a contagious condition. Autism i...
# 4   Estimates released by the Centers for Disease ...
# 5   It is likely that autism has always existed, b...
# 6   There is no cure for autism. However, early in...
# 7   There is no one single conclusive test for aut...
# 8   There is some controversy on the topic of whet...
# 9   Treatment for autism depends largely on the in...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#    https://www.autism.org.uk/advice-and-guidance/what-is-autism/asperger-syndrome  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  \nAutism, including Asperger syndrome, is much...
# 11  \nOver the years, different diagnostic labels ...
# 12  \nSome people see a formal diagnosis as an unh...
# 13  \nSome people with Asperger syndrome say the w...
# 14  \nThe characteristics of Asperger syndrome var...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#                   https://iancommunity.org/autism-faq  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   There is no blood test to diagnose autism spec...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  If your child has autism and you are intereste...
# 16  Immunizations are a cornerstone of public heal...
# 17  In most individuals it is currently not possib...
# 18  In order for autism research to advance, parti...
# 19  In the past five years, scientists have made s...
# 20  Just days after my live TED talk, the Centers ...
# 21  Research suggests that early intensive behavio...
# 22  The core features of autism are difficulties w...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#    https://icahn.mssm.edu/research/seaver/resources/autism-faqs  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   While there is no medical test for autism, an ...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Autism research is quickly developing across m...
# 20                                                NaN
# 21                                                NaN
# 22  The first step is a conversation with your chi...
# 23  Families have reported improvements in behavio...
# 24  In toddlers, obvious symptoms may not be prese...
# 25  The primary and first-line treatments include ...
# 26  There are several epidemiological studies that...
# 27  There is strong data indicating that genetics ...
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#    https://otsimo.com/en/frequently-asked-questions-autism/  \
# 0                                                 NaN
# 1   According to the U.S. Centers for Disease Cont...
# 2   You may think that something you did or ate or...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  Although mostly there is not one cause that ca...
# 29  Autism is a term that is constantly redefined ...
# 30  Autism spectrum disorder is an umbrella term u...
# 31  Every child has the right to get appropriate e...
# 32  You should consider consulting your doctor for...
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#                   https://rockmelon.com/about-autism/  \
# 0                                                 NaN
# 1   Recent studies have found that 1 in 59 childre...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   There are a number of different therapies avai...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30  Autism, also known as Autism Spectrum Disorder...
# 31                                                NaN
# 32                                                NaN
# 33  ASD is the acronym for ‘Autism Spectrum Disord...
# 34  Autism and learning disabilities can occur tog...
# 35  Autism spectrum disorder is more common in mal...
# 36  Currently, there is no single known cause for ...
# 37  Early intervention is recommended for all chil...
# 38  Evidence-based therapy means that there has be...
# 39  If you suspect your child has autism and you d...
# 40  If you suspect your child may have a developme...
# 41  Some of the common traits associated with auti...
# 42  The most common age for parents to first becom...
# 43  The simple answer is as early as possible. Tre...
# 44  There are a number of different therapies avai...
# 45  There are scientifically validated tests, such...
# 46  Yes, autism often occurs alongside other condi...
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#    https://www.amaze.org.au/understand-autism/about-autism/  \
# 0                                                 NaN
# 1                                                 NaN
# 2   There is no known cause of autism.Much researc...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47  Autism is a neurodevelopmental (meaning relate...
# 48  Autism may be present with other conditions. T...
# 49  Autistic people with complex support needs are...
# 50  The language we useis powerful, because it hel...
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#    https://autismrecovery.sg/autism/what-is-aspergers/  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51  For a person with Asperger's syndrome, reading...
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#    https://www.autism.org.sg/living-with-autism/what-is-autism
# 0                                                 NaN
# 1                                                 NaN
# 2   Although there are many theories, no one fully...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   Although there are many theories, no one fully...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30  Autism is a lifelong developmental disability ...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51  Asperger’s Syndrome is a form of autism, a con...
# 52  Autism is known as a spectrum condition as no ...
# 53                                                NaN
# 54                                                NaN

# %% [markdown]
# ## **Save Output**

# %%
df3.to_excel('ASDquestions10r.xlsx',index=False)
