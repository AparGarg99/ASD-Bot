# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from collections import Counter

# %%
df1 = pd.read_excel('Apar.xlsx',engine='openpyxl')
df2 = pd.read_excel('Gopan.xlsx',engine='openpyxl')
df3 = pd.read_excel('WeePing.xlsx',engine='openpyxl')

# %%
df = pd.concat([df1,df2,df3],axis=0)

# %%
df = df.sort_values(by=list(df.columns)).reset_index(drop=True)
df.head()
# Out:
#                                    Question  \
# 0  \nDo symptoms of autism change over time
# 1                   \nHow is autism treated
# 2       \nWhat disorders are related to ASD
# 3             \nWhat research is being done
# 4                 \nWhat role do genes play
#
#   https://autismnavigator.com/what-is-autism/  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   https://www.autism.org/is-it-autism/  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   https://www.autism.org/advice-for-parents/  \
# 0                                        NaN
# 1                                        NaN
# ...

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_text(sent):
    try:
        sent = sent.lower() # lowercase
        sent = re.sub(r'[^\w\s]', '', sent) # remove punctuations
        sent = re.sub('autism spectrum disorder','asd',sent) # Compress term
        sent = re.sub('autism','asd',sent) # Compress term
        sent = [w for w in sent.split() if not w in stop_words] # Remove stopwords
        sent = [lemmatizer.lemmatize(w) for w in sent] # Lemmatize
        sent = " ".join(sent)
        return sent
    except:
        pass

# %%
ques = df['Question'].apply(clean_text)

# %%
#ques = set(ques)

# %%
l=[]
for i in ques:
    try:
        for j in i.split():
            l.append(j)
    except:
        pass

# %%
d = Counter(l)

# %%
dict(sorted(d.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'asd': 121,
#  'child': 71,
#  'autistic': 26,
#  'cause': 13,
#  'treatment': 12,
#  'syndrome': 11,
#  'disorder': 11,
#  'asds': 11,
#  'diagnosed': 10,
#  'q': 10,
#  'vaccine': 10,
#  'medication': 9,
#  'symptom': 9,
#  'people': 8,
#  'true': 8,
#  'help': 8,
#  'common': 8,
#  'false': 7,
#  'parent': 7,
#  'therapy': 7,
#  'early': 7,
#  'education': 7,
#  'disability': 6,
#  'need': 6,
#  'disease': 6,
#  'diagnosis': 5,
#  'helpful': 5,
#  'find': 5,
#  'adult': 5,
#  'used': 5,
#  'asperger': 5,
#  'mitochondrial': 5,
#  'sign': 5,
#  'special': 5,
#  'time': 4,
#  'heard': 4,
#  'treating': 4,
#  'aspergers': 4,
#  'condition': 4,
#  'stress': 4,
#  'usually': 4,
#  'next': 4,
#  'family': 4,
#  'always': 4,
#  'trust': 4,
#  'relationship': 4,
#  'tell': 4,
#  'useful': 4,
#  'care': 4,
#  'change': 4,
#  'intervention': 4,
#  'behavioral': 4,
#  'service': 4,
#  'available': 3,
#  'difficult': 3,
#  'ive': 3,
#  'behavior': 3,
#  'sibling': 3,
#  'suffer': 3,
# ...
