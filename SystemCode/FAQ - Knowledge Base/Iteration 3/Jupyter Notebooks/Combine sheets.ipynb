# %%
#!pip install nltk
#!python -m nltk.downloader stopwords
#!python -m nltk.downloader
#!python -m nltk.downloader wordnet
#!pip install flashtext

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from flashtext import KeywordProcessor
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# # Combine Excel sheets

# %%
df1 = pd.read_excel('Apar.xlsx',engine='openpyxl')
df2 = pd.read_excel('Gopan.xlsx',engine='openpyxl')
df3 = pd.read_excel('WeePing.xlsx',engine='openpyxl')

# %%
df = pd.concat([df1,df2,df3],axis=0).dropna(how='all')
df['Question'] = df['Question'].apply(lambda x: x.strip())

# %%
df = df.sort_values(by=list(df.columns)).reset_index(drop=True)
df.head()
# Out:
#                                             Question  \
# 0                                              Adams
# 1  Are antipsychotic medications helpful in the t...
# 2  Are antipsychotic medications helpful in the t...
# 3  Are antipsychotic medications helpful in the t...
# 4  Are childhood vaccines responsible for autism ...
#
#   https://autismnavigator.com/what-is-autism/  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   https://www.autism.org/is-it-autism/  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#           https://www.autism.org/advice-for-parents/  \
# 0  Psychiatric medications are not well-tested in...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   https://www.autism.org/symptoms-of-autism/  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   https://www.autism.org/autism-prognosis/  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   https://autismcanada.org/autism-explained/  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   https://autismcanada.org/autism-explained/cooccurring-conditions/  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   https://autismcanada.org/autism-explained/screening-tools/  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   https://www.who.int/news-room/q-a-detail/autism-spectrum-disorders-(asd)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Available epidemiological data show that there...
#
#    ... https://birchtreecenter.org/learn/autism  \
# 0  ...                                      NaN
# 1  ...                                      NaN
# 2  ...                                      NaN
# 3  ...                                      NaN
# 4  ...                                      NaN
#
#   https://www.myautismteam.com/resources/autism-an-overview  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   https://www.autism.org.uk/advice-and-guidance/what-is-autism/asperger-syndrome  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   https://iancommunity.org/autism-faq  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   https://icahn.mssm.edu/research/seaver/resources/autism-faqs  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   https://otsimo.com/en/frequently-asked-questions-autism/  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   https://rockmelon.com/about-autism/  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   https://www.amaze.org.au/understand-autism/about-autism/  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   https://autismrecovery.sg/autism/what-is-aspergers/  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   https://www.autism.org.sg/living-with-autism/what-is-autism
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 35 columns]

# %% [markdown]
# # Group Questions

# %%
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def clean_text(sent):
    try:
        sent = sent.lower() # lowercase
        sent = re.sub(r'[^\w\s]', '', sent) # remove punctuations
        sent = re.sub('autism spectrum disorder','asd',sent) # Compress term
        sent = re.sub('autism','asd',sent) # Compress term
        sent = [w.lower() for w in sent.split() if not w.lower() in stop_words] # Remove stopwords
        sent = [lemmatizer.lemmatize(w) for w in sent]#lemantize words
        sent = " ".join(sent)
        return sent
    except:
        pass

# %%
df2 = df[['Question']].copy()

df2 = df2.drop_duplicates(subset ="Question")

ques = df2['Question'].apply(clean_text)

# %%
# KeyWords for Each Groups
oKeyWordDict = {
                'Treatment': ["vaccine ","disorder","treated","treatment ","treatments","therapy ","diagnosed ","syndrome","diagnosis ","medication ","respite","asperger ","mitochondrid ","diagnosed","treating","autistic","mitochondrial","vaccine"],
                'CausesAndSymptoms' : ["cause ","symptom ","symptoms","disability","behaviour","sign","early","cause","stress"],
                "RelationAndFamily" : ["people ","parent","education","educational","relationship","family","sibling","life","learning","parenting","home","future","help","need","guardianship","benefit","next"]
                }

# adding keywords
kp = KeywordProcessor()
kp.add_keywords_from_dict(oKeyWordDict)

df2['Group'] = ques.apply(lambda x: kp.extract_keywords(x, span_info = False))

# %%
df2
# Out:
#                                               Question  \
# 0                                                Adams
# 1    Are antipsychotic medications helpful in the t...
# 4    Are childhood vaccines responsible for autism ...
# 5    Are computers useful in the education of an au...
# 8    Are dietary interventions helpful to autistic ...
# ..                                                 ...
# 442  Why do concerns about mercury in vaccines pers...
# 443  Why do people diagnosed with autism spectrum d...
# 444  Why does a parent with an autistic child need ...
# 447                Will My Child Ever Be Able To Talk?
# 448                      Will My Child Ever Be Normal?
#
#                                                  Group
# 0                                                   []
# 1                                                   []
# 4                                          [Treatment]
# 5                       [RelationAndFamily, Treatment]
# 8                                          [Treatment]
# ..                                                 ...
# 442                                        [Treatment]
# 443                                        [Treatment]
# 444  [RelationAndFamily, Treatment, RelationAndFamily]
# 447                                                 []
# 448                                                 []
#
# [249 rows x 2 columns]

# %% [markdown]
# # Divide Groups among us

# %%
# Filter answered questions from df
answered_ques = df.dropna(subset=list(df.columns[1:]),how='all')

# %%
df2['# Groups'] = df2['Group'].apply(lambda x: len(set(x)))
df2['Answered'] = df2['Question'].apply(lambda x: x in list(answered_ques['Question']))

# %%
df2
# Out:
#                                               Question  \
# 0                                                Adams
# 1    Are antipsychotic medications helpful in the t...
# 4    Are childhood vaccines responsible for autism ...
# 5    Are computers useful in the education of an au...
# 8    Are dietary interventions helpful to autistic ...
# ..                                                 ...
# 442  Why do concerns about mercury in vaccines pers...
# 443  Why do people diagnosed with autism spectrum d...
# 444  Why does a parent with an autistic child need ...
# 447                Will My Child Ever Be Able To Talk?
# 448                      Will My Child Ever Be Normal?
#
#                                                  Group  # Groups  Answered
# 0                                                   []         0      True
# 1                                                   []         0     False
# 4                                          [Treatment]         1      True
# 5                       [RelationAndFamily, Treatment]         2     False
# 8                                          [Treatment]         1     False
# ..                                                 ...       ...       ...
# 442                                        [Treatment]         1      True
# 443                                        [Treatment]         1      True
# 444  [RelationAndFamily, Treatment, RelationAndFamily]         2     False
# 447                                                 []         0      True
# 448                                                 []         0      True
#
# [249 rows x 4 columns]

# %%
df2.to_excel("Apar_Grouped_Questions.xlsx",index=False)

# %%
df2['# Groups'].unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
df3 = df2.loc[df2['# Groups']==1]
df4 = df2.loc[df2['# Groups']!=1]

# %%
df3
# Out:
#                                               Question  \
# 4    Are childhood vaccines responsible for autism ...
# 8    Are dietary interventions helpful to autistic ...
# 11   Are medications useful in treating the behavio...
# 22   Are there other therapies that are useful in t...
# 29   Asperger syndrome is also on the spectrum of a...
# ..                                                 ...
# 428             Where do Autistic People Usually Live?
# 438  Why do I need to establish guardianship for my...
# 441  Why do children with autism have difficulty le...
# 442  Why do concerns about mercury in vaccines pers...
# 443  Why do people diagnosed with autism spectrum d...
#
#                                       Group  # Groups  Answered
# 4                               [Treatment]         1      True
# 8                               [Treatment]         1     False
# 11                   [Treatment, Treatment]         1     False
# 22                              [Treatment]         1      True
# 29                   [Treatment, Treatment]         1      True
# ..                                      ...       ...       ...
# 428                             [Treatment]         1     False
# 438  [RelationAndFamily, RelationAndFamily]         1     False
# 441                     [RelationAndFamily]         1      True
# 442                             [Treatment]         1      True
# 443                             [Treatment]         1      True
#
# [111 rows x 4 columns]

# %%
df3['Group'] = df3['Group'].apply(lambda x: x[0])
# Out:
# C:\Users\aparg\AppData\Local\Temp/ipykernel_19044/1627083287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Group'] = df3['Group'].apply(lambda x: x[0])

# %%
x=list(df3['Group'].unique())
x
# Out:
# ['Treatment', 'RelationAndFamily', 'CausesAndSymptoms']

# %%
y=list(df3['Answered'].unique())
y
# Out:
# [True, False]

# %%
df3.groupby(['Group']).size().reset_index(name='counts')
# Out:
#                Group  counts
# 0  CausesAndSymptoms      24
# 1  RelationAndFamily      34
# 2          Treatment      53

# %%
df3.groupby(['Group','Answered']).size().reset_index(name='counts')
# Out:
#                Group  Answered  counts
# 0  CausesAndSymptoms     False       2
# 1  CausesAndSymptoms      True      22
# 2  RelationAndFamily     False      14
# 3  RelationAndFamily      True      20
# 4          Treatment     False      20
# 5          Treatment      True      33

# %%
for i in x:
    for j in y:
        print(i,j)
        k = df3.loc[(df3['Group']==i) & (df3['Answered']==j)]
        k.to_excel("Divide_Groups/"+i+"_"+str(j)+".xlsx",index=False)
        print('*'*100)
# Out:
# Treatment True
# ****************************************************************************************************
# Treatment False
# ****************************************************************************************************
# RelationAndFamily True
# ****************************************************************************************************
# RelationAndFamily False
# ****************************************************************************************************
# CausesAndSymptoms True
# ****************************************************************************************************
# CausesAndSymptoms False
# ****************************************************************************************************

# %%
df4.to_excel("Divide_Groups/Others.xlsx",index=False)
